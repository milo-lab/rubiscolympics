# %%
import pandas as pd

# %%
uclust = pd.read_csv('../output/01_70p_tree/uclust_all_0.7.csv')
type_2_3 = pd.read_csv('../output/01_70p_tree/')
# Out:
#       Type  Cluster  Size   %Id Strand Qlo Tlo         Alignment  \
# 0        H        1   486  74.2      .   0   0         2I472M14D
# 1        H        2   464  72.6      .   0   0      I82M3I379M3D
# 2        H        2   449  74.1      .   0   0    3I72M3I377M10I
# 3        H        2   459  71.0      .   0   0       3I73M3I386M
# 4        H        2   459  74.9      .   0   0       3I79M3I380M
# 5        H        4   461  87.6      .   0   0            2D459M
# 6        H        2   461  71.7      .   0   0  3I38MD34M3I387MD
# 7        H        2   459  74.9      .   0   0       3I79M3I380M
# 8        H        6   444  80.9      .   0   0              444M
# 9        H        4   459  80.6      .   0   0              459M
# 10       H        4   459  84.1      .   0   0              459M
# 11       H        4   459  87.6      .   0   0              459M
# 12       H        1   479  85.4      .   0   0            474M5D
# ...
