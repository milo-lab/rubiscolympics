# %%
from ete3 import Tree, TreeStyle, NodeStyle
t = Tree('../output_itai/01_70p_tree/RaxML/RAxML_bipartitions.result',format=2)
t.set_outgroup(t.get_leaves_by_name('RBG_13_scaffold_9498_7')[0])

ts = TreeStyle()
ts.show_leaf_name = True
ts.mode = "c"
ts.arc_start = -120 # 0 degrees = 3 o'clock
ts.arc_span = 360
ts.branch_vertical_margin = 1
#t.show(tree_style=ts)

# %%
! mkdir -p ../output_itai/02_90p_tree
# !../bin/usearch11.0.667_i86linux32 -cluster_fast ../output_itai/00_100p_tree/uclust_all_1.faa -id 0.9 -uc ../output_itai/02_90p_tree/uclust_all_0.9.uc
# Out:
# The syntax of the command is incorrect.
# '..' is not recognized as an internal or external command,
# operable program or batch file.

# %%
parse_uclust(infile='../output_itai/02_90p_tree/uclust_all_0.9.uc',
             fasta='../output_itai/00_100p_tree/uclust_all_1.faa',
             outfasta='../output_itai/02_90p_tree/uclust_all_0.9.faa',
             outfile='../output_itai/02_90p_tree/uclust_all_0.9.csv'
            )

# %%
import pandas as pd

kinetic_data = pd.read_csv('../output_itai/00_100p_tree/uclust_all_1_kinetic_data.csv',names=['kinetic_ID'])
uc = pd.read_csv('../output_itai/01_70p_tree/uclust_all_0.7.csv')
uc = pd.read_csv('../output_itai/01_70p_tree/uclust_all_0.7.csv')
uc2 = uc.merge(kinetic_data,left_on='Query', right_on='kinetic_ID')
uc2['kinetic_flag'] = '-1'
uc2.loc[~uc2.kinetic_ID.isna(),'kinetic_flag'] = '1'
#lines = uc2['Target'].apply(lambda x: x.split(' ')[0]).values + ','+ uc2['kinetic_flag'].values+',-1\n'
#unique_lines = np.unique(lines)
uc2['ID'] = uc2['Target'].apply(lambda x: x.split(' ')[0])
uc['ID'] = uc['Target'].apply(lambda x: x.split(' ')[0])
all_leaves = uc.groupby('ID')['Type'].count()

# %%
uc_all = uc.merge(uc90,left_on='Query',right_on='Query',suffixes=('_70','_90'))
uc_all['ID'] = uc_all['Target_70'].apply(lambda x: x.split(' ')[0])
all_leaves = uc_all.groupby('ID')['Target_90'].nunique()
# Out:
# 162

# %%
import matplotlib as mp
from matplotlib import cm
ncol = 256
mg = cm.get_cmap('magma',lut=ncol)

# %%
x = 0
for leaf in t.traverse():
    if leaf.name == '':
        leaf.name = 'Int'+str(x)
        x = x+1
f = pd.DataFrame(pd.np.arange(0,257))
f['c'] = [mp.colors.to_hex(mg(x)) for x in f[0]]
#f.columns = ['x','c']
f.plot.scatter(x=0,y=0,c=f['c'])

mp.colors.to_hex(mg(3))
# Out:
# '#010108'

# %%
measurements = uc2.groupby('ID')['kinetic_flag'].count()
lines = []
max_frac = 0.0077191602340331384
for leaf in t.traverse():
    leaf.add_feature('num_measured',sum([measurements.loc[x.name] for x in leaf.get_leaves() if x.name in measurements.index]))
    leaf.add_feature('all_leaves',sum([all_leaves.loc[x.name] for x in leaf.get_leaves() if x.name in all_leaves.index]))
    mean_measured = pd.Series([measurements.loc[x.name] for x in leaf.get_leaves() if x.name in measurements.index]).mean()
    leaf.add_feature('mean_measured',pd.np.nanmax([mean_measured,0]))
    leaf.add_feature('frac_measured',leaf.num_measured/leaf.all_leaves)
    #leaf.line_width = 1+leaf.frac_measured/max_frac*4
    leaf.line_width = 1+leaf.mean_measured/200*4
    leaf.line_width = 1 + pd.np.log10(leaf.num_measured+1)/m*4
    m = 2.29
    #line = leaf.name + ' ' + 'branch ' + mp.colors.to_hex(mg(int(leaf.frac_measured/max_frac*ncol)), keep_alpha=False) + ' normal '+str(int(leaf.line_width))+'\n'
    #line = leaf.name + ' ' + 'branch ' + mp.colors.to_hex(mg(int(pd.np.log10(leaf.num_measured+1)/m*256)), keep_alpha=False) + ' normal '+str(int(leaf.line_width))+'\n'
    line = leaf.name + ' ' + 'branch ' + mp.colors.to_hex(mg(int(pd.np.log10(leaf.mean_measured+1)/m*256)), keep_alpha=False) + ' normal '+str(int(leaf.line_width))+'\n'
    #line = leaf.name + ' ' + 'branch ' + mp.colors.to_hex(mg(int(leaf.mean_measured)), keep_alpha=False) + ' normal '+str(int(leaf.line_width))+'\n'
    lines.append(line)
    #ns = NodeStyle()
    #ns["fgcolor"] = mp.colors.to_hex(mg(leaf.frac_measured*256), keep_alpha=False) 
    #print(ns['fgcolor'])
    #leaf.img_style = ns

# %%
pd.np.max([pd.np.log10(x.mean_measured+1) for x in t.traverse()])
# Out:
# 2.1986570869544226

# %%
lines
# Out:
# ['Int0 branch #0b0924 normal 1\n',
#  'Int1 branch #000004 normal 1\n',
#  'Int2 branch #0b0924 normal 1\n',
#  'RBCSeed_23 branch #000004 normal 1\n',
#  'RBCSeed_17 branch #000004 normal 1\n',
#  'RBC_16 branch #000004 normal 1\n',
#  'RBC_54 branch #000004 normal 1\n',
#  'Int3 branch #0b0924 normal 1\n',
#  'Int4 branch #000004 normal 1\n',
#  'Int5 branch #0b0924 normal 1\n',
#  'RBC_22 branch #000004 normal 1\n',
#  'RBC3_1 branch #000004 normal 1\n',
#  'Int6 branch #000004 normal 1\n',
#  'Int7 branch #0b0924 normal 1\n',
#  'RBC2_37 branch #000004 normal 1\n',
#  'Int8 branch #000004 normal 1\n',
#  'Int9 branch #0b0924 normal 1\n',
#  'gi|1247451339|gb|PCJ09133.1| branch #000004 normal 1\n',
#  'gi|1518545074|ref|WP_123402233.1| branch #000004 normal 1\n',
#  'gi|657350008|ref|WP_029406688.1| branch #000004 normal 1\n',
#  'Int10 branch #0d0a29 normal 1\n',
#  'Int11 branch #010005 normal 1\n',
#  'Int12 branch #0d0a29 normal 1\n',
#  'RBCSeed_11 branch #000004 normal 1\n',
#  'Int13 branch #010005 normal 1\n',
#  'Int14 branch #000004 normal 1\n',
#  'Int15 branch #010005 normal 1\n',
#  'Int16 branch #100b2d normal 1\n',
#  'RBCSeed_48 branch #000004 normal 1\n',
#  'RBCSeed_25 branch #010005 normal 1\n',
#  'RBC2_41 branch #000004 normal 1\n',
#  'gi|1247517904|gb|PCJ73671.1| branch #000004 normal 1\n',
#  'RBC_38 branch #000004 normal 1\n',
#  'Int17 branch #010005 normal 1\n',
#  'Int18 branch #100b2d normal 1\n',
#  'Int19 branch #000004 normal 1\n',
#  'gwf2_scaffold_583_77 branch #000004 normal 1\n',
#  'Int20 branch #010005 normal 1\n',
#  'Int21 branch #100b2d normal 1\n',
#  'Int22 branch #000004 normal 1\n',
#  'gi|503307351|ref|WP_013542012.1| branch #000004 normal 1\n',
#  'gi|1129860231|gb|OLS27808.1| branch #000004 normal 1\n',
#  'Int23 branch #010005 normal 1\n',
#  'Int24 branch #000004 normal 1\n',
#  'Int25 branch #160f3b normal 1\n',
#  'Int26 branch #010005 normal 1\n',
#  'Int27 branch #000004 normal 1\n',
#  'Int28 branch #000004 normal 1\n',
#  'Int29 branch #010005 normal 1\n',
#  'UBA4787contig_1245_80 branch #000004 normal 1\n',
#  'RBCSeed_26 branch #000004 normal 1\n',
#  'Int30 branch #000004 normal 1\n',
#  'Int31 branch #1c1044 normal 1\n',
#  'Int32 branch #010005 normal 1\n',
#  'Int33 branch #010005 normal 1\n',
#  'gi|1545546425|gb|RUM35076.1| branch #000004 normal 1\n',
#  'Int34 branch #000004 normal 1\n',
#  'gi|1572539448|emb|VDD88765.1| branch #000004 normal 1\n',
#  'Int35 branch #000004 normal 1\n',
#  'Int36 branch #000004 normal 1\n',
#  'RBCSeed_14 branch #010005 normal 1\n',
#  'gi|1572541027|emb|VDS11140.1| branch #000004 normal 1\n',
#  'gi|1308750508|gb|PKN02430.1| branch #000004 normal 1\n',
#  'Int37 branch #000004 normal 1\n',
#  'gi|1490259551|gb|RKZ25299.1| branch #000004 normal 1\n',
#  'Int38 branch #1c1044 normal 1\n',
#  'Int39 branch #000004 normal 1\n',
#  'Int40 branch #010005 normal 1\n',
#  'Int41 branch #000004 normal 1\n',
#  'Int42 branch #010005 normal 1\n',
#  'Int43 branch #000004 normal 1\n',
#  'ncbi_AWOG01000022.1_5 branch #000004 normal 1\n',
#  'gi|1572540309|emb|VDD89255.1| branch #000004 normal 1\n',
#  'gi|1572540265|emb|VDD89220.1| branch #000004 normal 1\n',
#  'Int44 branch #000004 normal 1\n',
#  'Int45 branch #000004 normal 1\n',
#  'gi|1278491485|gb|PJA14308.1| branch #000004 normal 1\n',
#  'RBCSeed_30 branch #000004 normal 1\n',
#  'Int46 branch #000004 normal 1\n',
#  'Int47 branch #1c1044 normal 1\n',
#  'gi|1063920603|gb|ODS42869.1| branch #000004 normal 1\n',
#  'Int48 branch #000004 normal 1\n',
#  'Int49 branch #010005 normal 1\n',
#  'Int50 branch #000004 normal 1\n',
#  'UBA96contig_21807_17 branch #000004 normal 1\n',
#  'gi|1277766580|gb|PIT84221.1| branch #000004 normal 1\n',
#  'UBA93contig_1572_78 branch #000004 normal 1\n',
#  'Int51 branch #010005 normal 1\n',
#  'gi|1490108493|gb|RKX98512.1| branch #000004 normal 1\n',
#  'gi|1572540269|emb|VDD89222.1| branch #000004 normal 1\n',
#  'Int52 branch #000004 normal 1\n',
#  'Int53 branch #000004 normal 1\n',
#  'Int54 branch #000004 normal 1\n',
#  'gi|1572541005|emb|VDS11129.1| branch #000004 normal 1\n',
#  'gi|506220048|ref|WP_015739823.1| branch #000004 normal 1\n',
#  'gi|1383132961|ref|WP_108308545.1| branch #000004 normal 1\n',
#  'RBG_16_CP_70_13_RBG_16_scaffold_22096_8 branch #000004 normal 1\n',
#  'Int55 branch #1c1044 normal 1\n',
#  'gi|494102711|ref|WP_007043498.1| branch #000004 normal 1\n',
#  'gi|505096769|ref|WP_015283871.1| branch #000004 normal 1\n',
#  'Int56 branch #000004 normal 1\n',
#  'Int57 branch #010005 normal 1\n',
#  'Int58 branch #000004 normal 1\n',
#  'Int59 branch #000004 normal 1\n',
#  'Int60 branch #000004 normal 1\n',
#  'Int61 branch #010005 normal 1\n',
#  'img_2698597071_3 branch #000004 normal 1\n',
#  'Int62 branch #000004 normal 1\n',
#  'Int63 branch #000004 normal 1\n',
#  'Int64 branch #000004 normal 1\n',
#  'Int65 branch #000004 normal 1\n',
#  'Int66 branch #000004 normal 1\n',
#  'Int67 branch #000004 normal 1\n',
#  'Int68 branch #1c1044 normal 1\n',
#  'gi|1491126887|gb|RLG17049.1| branch #000004 normal 1\n',
#  'Int69 branch #000004 normal 1\n',
#  'Int70 branch #010005 normal 1\n',
#  'Int71 branch #000004 normal 1\n',
#  'Int72 branch #000004 normal 1\n',
#  'Int73 branch #000004 normal 1\n',
#  'gi|1604502740|gb|TFG04138.1| branch #000004 normal 1\n',
#  'gi|1604516179|gb|TFG16462.1| branch #000004 normal 1\n',
#  'Int74 branch #000004 normal 1\n',
#  'Int75 branch #000004 normal 1\n',
#  'Int76 branch #000004 normal 1\n',
#  'Int77 branch #010005 normal 1\n',
#  'mol321605030446_1_Gottesmanbacteria branch #000004 normal 1\n',
#  'gwc2_scaffold_9210_4 branch #000004 normal 1\n',
#  'gi|1572539414|emb|VDD88743.1| branch #000004 normal 1\n',
#  'gi|1572540257|emb|VDD89216.1| branch #000004 normal 1\n',
#  'cg1_0.2_scaffold_3272_c_4 branch #000004 normal 1\n',
#  'gi|1572540207|emb|VDD89172.1| branch #000004 normal 1\n',
#  'Int78 branch #000004 normal 1\n',
#  'UBA1441contig_19953_11 branch #000004 normal 1\n',
#  'Int79 branch #000004 normal 1\n',
#  'Int80 branch #000004 normal 1\n',
#  'gi|1498020247|gb|RMF04955.1| branch #000004 normal 1\n',
#  'gi|1236894643|ref|WP_095045405.1| branch #000004 normal 1\n',
#  'Int81 branch #1c1044 normal 1\n',
#  'Int82 branch #000004 normal 1\n',
#  'gi|1491127331|gb|RLG17436.1| branch #000004 normal 1\n',
#  'gi|1491129072|gb|RLG18973.1| branch #000004 normal 1\n',
#  'Int83 branch #000004 normal 1\n',
#  'Int84 branch #010005 normal 1\n',
#  'gi|1491172809|gb|RLG56183.1| branch #000004 normal 1\n',
#  'Int85 branch #000004 normal 1\n',
#  'gi|1491344295|gb|RLJ03461.1| branch #000004 normal 1\n',
#  'gi|1576514818|gb|RZN69655.1| branch #000004 normal 1\n',
#  'gi|1491102575|gb|RLF96472.1| branch #000004 normal 1\n',
#  'Int86 branch #000004 normal 1\n',
#  'gi|1576493154|gb|RZN49008.1| branch #000004 normal 1\n',
#  'gi|1004825877|gb|KYC51028.1| branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620106.270.0.1-0.22_8536_3 branch #000004 normal 1\n',
#  'rifcsplowo2_01_scaffold_269943_3 branch #000004 normal 1\n',
#  'Int87 branch #000004 normal 1\n',
#  'gi|1491067218|gb|RLF68008.1| branch #000004 normal 1\n',
#  'gi|1604509776|gb|TFG10482.1| branch #000004 normal 1\n',
#  'Int88 branch #010005 normal 1\n',
#  'gi|1572540135|emb|VDD89122.1| branch #000004 normal 1\n',
#  'gi|1572540093|emb|VDD89095.1| branch #000004 normal 1\n',
#  'gi|1278474723|gb|PIZ99488.1| branch #000004 normal 1\n',
#  'gi|1278699910|gb|PJC01515.1| branch #000004 normal 1\n',
#  'Int89 branch #000004 normal 1\n',
#  'Int90 branch #000004 normal 1\n',
#  'Int91 branch #1c1044 normal 1\n',
#  'RBC_41 branch #000004 normal 1\n',
#  'gi|1519878934|gb|RPI23753.1| branch #000004 normal 1\n',
#  'gi|1519885519|gb|RPI29221.1| branch #000004 normal 1\n',
#  'gi|1572540149|emb|VDD89129.1| branch #000004 normal 1\n',
#  'Int92 branch #000004 normal 1\n',
#  'Int93 branch #000004 normal 1\n',
#  'Int94 branch #010005 normal 1\n',
#  'gi|1491329535|gb|RLI90645.1| branch #000004 normal 1\n',
#  'Int95 branch #000004 normal 1\n',
#  'gi|1124900570|gb|OKY77189.1| branch #000004 normal 1\n',
#  'gi|985667650|gb|KXA98893.1| branch #000004 normal 1\n',
#  'gi|1491337503|gb|RLI97578.1| branch #000004 normal 1\n',
#  'gi|1231997338|gb|OYT57613.1| branch #000004 normal 1\n',
#  'Int96 branch #000004 normal 1\n',
#  'Int97 branch #010005 normal 1\n',
#  'Int98 branch #000004 normal 1\n',
#  'Int99 branch #000004 normal 1\n',
#  'CG_201511_scaffold_25419_1 branch #000004 normal 1\n',
#  'gi|1278357258|gb|PIY97215.1| branch #000004 normal 1\n',
#  'Int100 branch #000004 normal 1\n',
#  'Int101 branch #1c1044 normal 1\n',
#  'CG_201501_scaffold_106789_1 branch #000004 normal 1\n',
#  'gi|1276400916|gb|PIN72082.1| branch #000004 normal 1\n',
#  'Int102 branch #000004 normal 1\n',
#  'Int103 branch #000004 normal 1\n',
#  'Int104 branch #000004 normal 1\n',
#  'Int105 branch #010005 normal 1\n',
#  'gi|1491327848|gb|RLI89213.1| branch #000004 normal 1\n',
#  'Int106 branch #000004 normal 1\n',
#  'Int107 branch #000004 normal 1\n',
#  'Int108 branch #000004 normal 1\n',
#  'Int109 branch #010005 normal 1\n',
#  'Int110 branch #000004 normal 1\n',
#  'gwa2_scaffold_913_23 branch #000004 normal 1\n',
#  'gi|1572539540|emb|VDD88835.1| branch #000004 normal 1\n',
#  'gi|1572539694|emb|VDD88949.1| branch #000004 normal 1\n',
#  'Int111 branch #000004 normal 1\n',
#  'gi|664643791|gb|AIF31469.1| branch #000004 normal 1\n',
#  'gi|1497896382|gb|RME08239.1| branch #000004 normal 1\n',
#  'Int112 branch #040414 normal 1\n',
#  'Int113 branch #2d1161 normal 1\n',
#  'Int114 branch #000004 normal 1\n',
#  'gi|1572539602|emb|VDD88880.1| branch #000004 normal 1\n',
#  'Int115 branch #000004 normal 1\n',
#  'Int116 branch #000004 normal 1\n',
#  'Int117 branch #000004 normal 1\n',
#  'gi|1491340862|gb|RLJ00545.1| branch #000004 normal 1\n',
#  'Int118 branch #000004 normal 1\n',
#  'Int119 branch #010005 normal 1\n',
#  'gi|1231991901|gb|OYT52763.1| branch #000004 normal 1\n',
#  'gi|1491335530|gb|RLI95896.1| branch #000004 normal 1\n',
#  'gi|1129850257|gb|OLS18291.1| branch #000004 normal 1\n',
#  'Int120 branch #000004 normal 1\n',
#  'Int121 branch #000004 normal 1\n',
#  'Int122 branch #000004 normal 1\n',
#  'Int123 branch #000004 normal 1\n',
#  'Int124 branch #010005 normal 1\n',
#  'TARA_064.SAMEA2620815.1000.0.22-3_688879_13 branch #000004 normal 1\n',
#  'Int125 branch #000004 normal 1\n',
#  'Int126 branch #000004 normal 1\n',
#  'Int127 branch #000004 normal 1\n',
#  'gi|1268874123|ref|WP_099081945.1| branch #000004 normal 1\n',
#  'Int128 branch #040414 normal 1\n',
#  'Int129 branch #010106 normal 1\n',
#  'Int130 branch #451077 normal 2\n',
#  'gi|1572540151|emb|VDD89130.1| branch #000004 normal 1\n',
#  'Int131 branch #000004 normal 1\n',
#  'Int132 branch #000004 normal 1\n',
#  'Int133 branch #000004 normal 1\n',
#  'UBA119contig_8444_4 branch #000004 normal 1\n',
#  'Int134 branch #000004 normal 1\n',
#  'gi|1572539444|emb|VDD88763.1| branch #000004 normal 1\n',
#  'RBG_16_Archaea_36_9_RBG_16_scaffold_36_87 branch #000004 normal 1\n',
#  'gi|1572540197|emb|VDD89167.1| branch #000004 normal 1\n',
#  'Int135 branch #000004 normal 1\n',
#  'Int136 branch #010005 normal 1\n',
#  'Int137 branch #000004 normal 1\n',
#  'Int138 branch #000004 normal 1\n',
#  'gi|1491146544|gb|RLG33748.1| branch #000004 normal 1\n',
#  'Int139 branch #000004 normal 1\n',
#  'gi|757145770|ref|WP_042699978.1| branch #000004 normal 1\n',
#  'Int140 branch #000004 normal 1\n',
#  'Int141 branch #000004 normal 1\n',
#  'gi|1374493067|gb|PTD93810.1| branch #000004 normal 1\n',
#  'gi|1490928187|gb|RLE56370.1| branch #000004 normal 1\n',
#  'Int142 branch #010005 normal 1\n',
#  'gi|1491110889|gb|RLG03271.1| branch #000004 normal 1\n',
#  'gi|1490949061|gb|RLE73159.1| branch #000004 normal 1\n',
#  'Int143 branch #000004 normal 1\n',
#  'CG03_land_8_20_14_0.80_scaffold_45401_2 branch #000004 normal 1\n',
#  'RIFCSPHIGHO2_12_FULL_OD1_42_14_rifcsphigho2_12_scaffold_6219_7 branch #000004 normal 1\n',
#  'CG22_combo_CG1013_8_21_14_all_scaffold_27032_2_Parcubacteria branch #000004 normal 1\n',
#  'gi|1572540301|emb|VDD89247.1| branch #000004 normal 1\n',
#  'gi|1463752065|ref|WP_116707191.1| branch #000004 normal 1\n',
#  'Int144 branch #040414 normal 1\n',
#  'Int145 branch #010106 normal 1\n',
#  'Int146 branch #000004 normal 1\n',
#  'gi|518331021|ref|WP_019501228.1| branch #e34e65 normal 4\n',
#  'Int147 branch #03030f normal 1\n',
#  'gi|1572540031|emb|VDD89050.1| branch #000004 normal 1\n',
#  'gi|1572540311|emb|VDD89256.1| branch #000004 normal 1\n',
#  'Int148 branch #000004 normal 1\n',
#  'Int149 branch #000004 normal 1\n',
#  'Int150 branch #000004 normal 1\n',
#  'Int151 branch #000004 normal 1\n',
#  'gi|1572540091|emb|VDD89094.1| branch #000004 normal 1\n',
#  'gi|1572539472|emb|VDD88777.1| branch #000004 normal 1\n',
#  'gi|1572539945|emb|VDD88978.1| branch #000004 normal 1\n',
#  'gi|1572540255|emb|VDD89215.1| branch #000004 normal 1\n',
#  'Int152 branch #000004 normal 1\n',
#  'Int153 branch #010005 normal 1\n',
#  'gi|1572541037|emb|VDS11145.1| branch #000004 normal 1\n',
#  'Int154 branch #000004 normal 1\n',
#  'gi|1166579504|gb|OPX60608.1| branch #000004 normal 1\n',
#  'Int155 branch #000004 normal 1\n',
#  'Int156 branch #000004 normal 1\n',
#  'gi|499768544|ref|WP_011449278.1| branch #000004 normal 1\n',
#  'gi|1308448374|gb|PKK86116.1| branch #000004 normal 1\n',
#  'gi|1600134581|gb|TET90869.1| branch #000004 normal 1\n',
#  'Int157 branch #000004 normal 1\n',
#  'Int158 branch #000004 normal 1\n',
#  'Int159 branch #000004 normal 1\n',
#  'Int160 branch #010005 normal 1\n',
#  'Int161 branch #000004 normal 1\n',
#  'Int162 branch #000004 normal 1\n',
#  'Int163 branch #000004 normal 1\n',
#  'Int164 branch #040414 normal 1\n',
#  'gi|60476014|gb|AAX21148.1| branch #000004 normal 1\n',
#  'gi|523387592|emb|CDF56957.1| branch #010106 normal 1\n',
#  'gi|1064963083|ref|WP_069472570.1| branch #000004 normal 1\n',
#  'gi|760494846|gb|AJP31461.1| branch #000004 normal 1\n',
#  'Int165 branch #010106 normal 1\n',
#  'gi|358252603|gb|AEU04903.1| branch #06051a normal 1\n',
#  'gi|1572539646|emb|VDD88909.1| branch #000004 normal 1\n',
#  'Int166 branch #000004 normal 1\n',
#  'gi|1572539456|emb|VDD88769.1| branch #000004 normal 1\n',
#  'Int167 branch #000004 normal 1\n',
#  'Int168 branch #000004 normal 1\n',
#  'gi|1572539558|emb|VDD88848.1| branch #000004 normal 1\n',
#  'Int169 branch #000004 normal 1\n',
#  'Int170 branch #000004 normal 1\n',
#  'Int171 branch #000004 normal 1\n',
#  'Int172 branch #000004 normal 1\n',
#  'Int173 branch #000004 normal 1\n',
#  'Int174 branch #010005 normal 1\n',
#  'gi|1231975900|gb|OYT38348.1| branch #000004 normal 1\n',
#  'Int175 branch #000004 normal 1\n',
#  'Int176 branch #000004 normal 1\n',
#  'gi|944558241|gb|KQM10927.1| branch #000004 normal 1\n',
#  'gi|1011504110|ref|WP_062398647.1| branch #000004 normal 1\n',
#  'Int177 branch #000004 normal 1\n',
#  'gi|1576506363|gb|RZN61779.1| branch #000004 normal 1\n',
#  'gi|1374493844|gb|PTD94544.1| branch #000004 normal 1\n',
#  'Int178 branch #000004 normal 1\n',
#  'gi|1561394811|ref|WP_128567054.1| branch #000004 normal 1\n',
#  'gi|1497346061|ref|WP_121919240.1| branch #000004 normal 1\n',
#  'Int179 branch #000004 normal 1\n',
#  'Int180 branch #010005 normal 1\n',
#  'Int181 branch #010005 normal 1\n',
#  'gi|1490950958|gb|RLE74556.1| branch #000004 normal 1\n',
#  'Int182 branch #000004 normal 1\n',
#  'Int183 branch #000004 normal 1\n',
#  'gi|1483843213|gb|RJS75034.1| branch #000004 normal 1\n',
#  'gi|384071366|emb|CCG54760.1| branch #000004 normal 1\n',
#  'gi|390190374|gb|AFL65679.1| branch #000004 normal 1\n',
#  'Int184 branch #010108 normal 1\n',
#  'Int185 branch #090720 normal 1\n',
#  'gi|1271067907|gb|PHT72509.1| branch #010106 normal 1\n',
#  'Int186 branch #000004 normal 1\n',
#  'gi|1572539943|emb|VDD88977.1| branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620106.270.0.1-0.22_12523_5 branch #000004 normal 1\n',
#  'gi|1572539342|emb|VDD88670.1| branch #000004 normal 1\n',
#  'TARA_138.SAMEA2623390.450.0.22-3_117554_31 branch #000004 normal 1\n',
#  'CG_201513_scaffold_88435_1 branch #000004 normal 1\n',
#  'gi|1572539402|emb|VDD88726.1| branch #000004 normal 1\n',
#  'Int187 branch #000004 normal 1\n',
#  'Int188 branch #000004 normal 1\n',
#  'gi|1572540307|emb|VDD89250.1| branch #000004 normal 1\n',
#  'Int189 branch #000004 normal 1\n',
#  'TARA_037.SAMEA2619974.600.0.1-0.22_3458_1 branch #000004 normal 1\n',
#  'gi|1572539330|emb|VDD88628.1| branch #000004 normal 1\n',
#  'Int190 branch #000004 normal 1\n',
#  'Int191 branch #000004 normal 1\n',
#  'Int192 branch #000004 normal 1\n',
#  'Int193 branch #000004 normal 1\n',
#  'Int194 branch #000004 normal 1\n',
#  'Int195 branch #010005 normal 1\n',
#  'gi|1276406858|gb|PIN77236.1| branch #000004 normal 1\n',
#  'gi|1572540133|emb|VDD89118.1| branch #000004 normal 1\n',
#  'gi|505304629|ref|WP_015491731.1| branch #000004 normal 1\n',
#  'gi|851218974|ref|WP_048113196.1| branch #000004 normal 1\n',
#  'gi|757152186|ref|WP_042706367.1| branch #000004 normal 1\n',
#  'gi|490178889|ref|WP_004077508.1| branch #000004 normal 1\n',
#  'Int196 branch #000004 normal 1\n',
#  'gi|1604689070|gb|TFH41752.1| branch #000004 normal 1\n',
#  'Int197 branch #000004 normal 1\n',
#  'Int198 branch #000004 normal 1\n',
#  'Int199 branch #000004 normal 1\n',
#  'Int200 branch #010005 normal 1\n',
#  'gi|1574435471|dbj|GCF94976.1| branch #000004 normal 1\n',
#  'Int201 branch #010005 normal 1\n',
#  'gi|939574975|gb|KPV64794.1| branch #000004 normal 1\n',
#  'Int202 branch #000004 normal 1\n',
#  'Int203 branch #000004 normal 1\n',
#  'gi|1232003240|gb|OYT62983.1| branch #000004 normal 1\n',
#  'Int204 branch #000004 normal 1\n',
#  'gi|29726049|gb|AAL46534.1| branch #010108 normal 1\n',
#  'gi|703265142|emb|CDI73524.1| branch #090720 normal 1\n',
#  'TARA_084.SAMEA2621487.5.0.22-3_1652747_5 branch #000004 normal 1\n',
#  'Int205 branch #000004 normal 1\n',
#  'Int206 branch #000004 normal 1\n',
#  'gi|1491188135|gb|RLG69381.1| branch #000004 normal 1\n',
#  'Int207 branch #000004 normal 1\n',
#  'gi|1490906874|gb|RLE38780.1| branch #000004 normal 1\n',
#  'Int208 branch #000004 normal 1\n',
#  'gi|1572540083|emb|VDD89090.1| branch #000004 normal 1\n',
#  'Int209 branch #000004 normal 1\n',
#  'Int210 branch #000004 normal 1\n',
#  'gi|1572539438|emb|VDD88760.1| branch #000004 normal 1\n',
#  'TARA_037.SAMEA2619974.600.0.1-0.22_4142_3 branch #000004 normal 1\n',
#  'Int211 branch #000004 normal 1\n',
#  'gi|1304872869|gb|PKG32658.1| branch #000004 normal 1\n',
#  'gi|1572540251|emb|VDD89211.1| branch #000004 normal 1\n',
#  'gi|1491348369|gb|RLJ06804.1| branch #000004 normal 1\n',
#  'Int212 branch #000004 normal 1\n',
#  'gi|1231980590|gb|OYT42730.1| branch #000004 normal 1\n',
#  'Int213 branch #000004 normal 1\n',
#  'Int214 branch #000004 normal 1\n',
#  'Int215 branch #010005 normal 1\n',
#  'gi|116666356|gb|ABK15383.1| branch #000004 normal 1\n',
#  'Int216 branch #000004 normal 1\n',
#  'RBG_19FT_COMBO_Aminicenantes-rel_58_17_rbg_19ft_combo_scaffold_871_21 branch #000004 normal 1\n',
#  'Int217 branch #000004 normal 1\n',
#  'Int218 branch #000004 normal 1\n',
#  'Int219 branch #000004 normal 1\n',
#  'TARA_137.SAMEA2623295.40.0.22-3_111714_43 branch #000004 normal 1\n',
#  'Int220 branch #000004 normal 1\n',
#  'Int221 branch #000004 normal 1\n',
#  'Int222 branch #010005 normal 1\n',
#  'GWB1_Spirochaetes_66_5_GWB1_scaffold_33904_7 branch #000004 normal 1\n',
#  'Int223 branch #010005 normal 1\n',
#  'Int224 branch #000004 normal 1\n',
#  'gi|1491182069|gb|RLG64092.1| branch #000004 normal 1\n',
#  'gi|1491255015|gb|RLI26502.1| branch #000004 normal 1\n',
#  'gi|1490946181|gb|RLE70929.1| branch #000004 normal 1\n',
#  'gi|327365904|gb|AEA52294.1| branch #000004 normal 1\n',
#  'gi|381414097|gb|AFG29032.1| branch #000004 normal 1\n',
#  'Int225 branch #000004 normal 1\n',
#  'gi|1271003797|gb|PHT40438.1| branch #000004 normal 1\n',
#  'gi|9719194|gb|AAF97676.1| branch #000004 normal 1\n',
#  'gi|14326404|gb|AAK60257.1| branch #000004 normal 1\n',
#  'Int226 branch #000004 normal 1\n',
#  'Int227 branch #000004 normal 1\n',
#  'TARA_037.SAMEA2619974.600.0.1-0.22_2908_29 branch #000004 normal 1\n',
#  'gi|1572540057|emb|VDD89073.1| branch #000004 normal 1\n',
#  'Int228 branch #000004 normal 1\n',
#  'gi|1491124592|gb|RLG15067.1| branch #000004 normal 1\n',
#  'gi|1490905582|gb|RLE37725.1| branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620106.270.0.1-0.22_3169_5 branch #000004 normal 1\n',
#  'TARA_037.SAMEA2619974.600.0.1-0.22_11634_5 branch #000004 normal 1\n',
#  'Int229 branch #000004 normal 1\n',
#  'gi|1491338101|gb|RLI98096.1| branch #000004 normal 1\n',
#  'gi|1490041904|gb|RKX41820.1| branch #000004 normal 1\n',
#  'Int230 branch #000004 normal 1\n',
#  'Int231 branch #000004 normal 1\n',
#  'gi|1491131059|gb|RLG20628.1| branch #000004 normal 1\n',
#  'Int232 branch #000004 normal 1\n',
#  'RIFCSPHIGHO2_01_FULL_OD1_39_14_rifcsphigho2_01_scaffold_71123_4 branch #000004 normal 1\n',
#  'Int233 branch #010005 normal 1\n',
#  'gi|941507471|gb|KQC16418.1| branch #000004 normal 1\n',
#  'gi|1166683360|gb|OPY49909.1| branch #000004 normal 1\n',
#  'gi|1277856461|gb|PIU65234.1| branch #000004 normal 1\n',
#  'RBG_19FT_COMBO_GAL15_69_19_rbg_19ft_combo_scaffold_2139_2 branch #000004 normal 1\n',
#  'Int234 branch #000004 normal 1\n',
#  'Int235 branch #000004 normal 1\n',
#  'gi|966474243|ref|WP_058505004.1| branch #000004 normal 1\n',
#  'GWA2_Elusimicrobia_69_24_gwa2_scaffold_146_25 branch #000004 normal 1\n',
#  'gi|1498126395|gb|RMF91127.1| branch #000004 normal 1\n',
#  'gi|1334821814|dbj|GBE18173.1| branch #000004 normal 1\n',
#  'Int236 branch #000004 normal 1\n',
#  'Int237 branch #000004 normal 1\n',
#  'Int238 branch #000004 normal 1\n',
#  'Int239 branch #010005 normal 1\n',
#  'Int240 branch #010005 normal 1\n',
#  'Int241 branch #000004 normal 1\n',
#  'gi|1490924944|gb|RLE53433.1| branch #000004 normal 1\n',
#  'gi|1576499582|gb|RZN55275.1| branch #000004 normal 1\n',
#  'gi|1271092163|gb|PHT86516.1| branch #000004 normal 1\n',
#  'gi|1271023430|gb|PHT50236.1| branch #000004 normal 1\n',
#  'gi|1572541035|emb|VDS11144.1| branch #000004 normal 1\n',
#  'Int242 branch #000004 normal 1\n',
#  'Int243 branch #000004 normal 1\n',
#  'Int244 branch #000004 normal 1\n',
#  'Int245 branch #000004 normal 1\n',
#  'Int246 branch #000004 normal 1\n',
#  'gi|1572539997|emb|VDD89027.1| branch #000004 normal 1\n',
#  'Int247 branch #000004 normal 1\n',
#  'Int248 branch #000004 normal 1\n',
#  'gi|1277807326|gb|PIU21541.1| branch #000004 normal 1\n',
#  'Int249 branch #000004 normal 1\n',
#  'Int250 branch #000004 normal 1\n',
#  'Int251 branch #000004 normal 1\n',
#  'gi|1572539588|emb|VDD88873.1| branch #000004 normal 1\n',
#  'Int252 branch #010005 normal 1\n',
#  'Int253 branch #000004 normal 1\n',
#  'TARA_146.SAMEA2623673.5.0.22-3_461367_4 branch #000004 normal 1\n',
#  'Int254 branch #000004 normal 1\n',
#  'CG_201501t_scaffold_2353_6_PHAGE branch #000004 normal 1\n',
#  'Int255 branch #000004 normal 1\n',
#  'Int256 branch #000004 normal 1\n',
#  'Int257 branch #000004 normal 1\n',
#  'Int258 branch #000004 normal 1\n',
#  'Int259 branch #000004 normal 1\n',
#  'RBG_13_Nitrospira_39_12_RBG_13_scaffold_5114_2 branch #000004 normal 1\n',
#  'gi|1600091628|gb|TET55442.1| branch #000004 normal 1\n',
#  'gi|1308594295|gb|PKL91770.1| branch #000004 normal 1\n',
#  'Int260 branch #010005 normal 1\n',
#  'Int261 branch #000004 normal 1\n',
#  'Int262 branch #010005 normal 1\n',
#  'Int263 branch #000004 normal 1\n',
#  'Int264 branch #000004 normal 1\n',
#  'gi|1572540121|emb|VDD89112.1| branch #000004 normal 1\n',
#  'Int265 branch #000004 normal 1\n',
#  'gi|502959403|ref|WP_013194379.1| branch #000004 normal 1\n',
#  'Int266 branch #000004 normal 1\n',
#  'gi|1490910791|gb|RLE41930.1| branch #000004 normal 1\n',
#  'gi|1572539596|emb|VDD88877.1| branch #000004 normal 1\n',
#  'Int267 branch #000004 normal 1\n',
#  'gi|1572540513|emb|VDD89261.1| branch #000004 normal 1\n',
#  'gi|1572541033|emb|VDS11143.1| branch #000004 normal 1\n',
#  'UBA153contig_35505_2 branch #000004 normal 1\n',
#  'gi|1572540003|emb|VDD89030.1| branch #000004 normal 1\n',
#  'Int268 branch #000004 normal 1\n',
#  'Int269 branch #000004 normal 1\n',
#  'Int270 branch #000004 normal 1\n',
#  'Int271 branch #000004 normal 1\n',
#  'rifcsplowo2_01_scaffold_118545_1 branch #000004 normal 1\n',
#  'Int272 branch #000004 normal 1\n',
#  'gi|1572540117|emb|VDD89110.1| branch #000004 normal 1\n',
#  'Int273 branch #000004 normal 1\n',
#  'Int274 branch #000004 normal 1\n',
#  'Int275 branch #000004 normal 1\n',
#  'Int276 branch #010005 normal 1\n',
#  'Int277 branch #000004 normal 1\n',
#  'Int278 branch #000004 normal 1\n',
#  'Int279 branch #000004 normal 1\n',
#  'TARA_037.SAMEA2619974.600.0.1-0.22_2167_20 branch #000004 normal 1\n',
#  'Int280 branch #000004 normal 1\n',
#  'Int281 branch #000004 normal 1\n',
#  'Int282 branch #000004 normal 1\n',
#  'Int283 branch #000004 normal 1\n',
#  'Int284 branch #000004 normal 1\n',
#  'gi|1224480780|ref|WP_092501847.1| branch #000004 normal 1\n',
#  'gi|1341957669|ref|WP_103954334.1| branch #000004 normal 1\n',
#  'gi|1591524417|ref|WP_131807513.1| branch #000004 normal 1\n',
#  'Int285 branch #000004 normal 1\n',
#  'Int286 branch #000004 normal 1\n',
#  'Int287 branch #010005 normal 1\n',
#  'Int288 branch #000004 normal 1\n',
#  'RBG_16_DPX1_48_10_RBG_16_scaffold_502_2 branch #000004 normal 1\n',
#  'Int289 branch #000004 normal 1\n',
#  'Int290 branch #000004 normal 1\n',
#  'Int291 branch #010005 normal 1\n',
#  'gi|501941531|ref|WP_012676081.1| branch #000004 normal 1\n',
#  'Int292 branch #000004 normal 1\n',
#  'Int293 branch #000004 normal 1\n',
#  'gi|1276923421|gb|PIP41828.1| branch #000004 normal 1\n',
#  'gi|1572541021|emb|VDS11137.1| branch #000004 normal 1\n',
#  'TARA_037.SAMEA2619974.600.0.1-0.22_4356_11 branch #000004 normal 1\n',
#  'gi|505137916|ref|WP_015325018.1| branch #000004 normal 1\n',
#  'gi|851308879|ref|WP_048172188.1| branch #000004 normal 1\n',
#  'Int294 branch #000004 normal 1\n',
#  'Int295 branch #000004 normal 1\n',
#  'gi|1572539494|emb|VDD88792.1| branch #000004 normal 1\n',
#  'CG10_big_fil_rev_8_21_14_0.10_scaffold_63175_3 branch #000004 normal 1\n',
#  'Int296 branch #000004 normal 1\n',
#  'Int297 branch #000004 normal 1\n',
#  'gi|1572539630|emb|VDD88898.1| branch #000004 normal 1\n',
#  'rifcsphigho2_02_scaffold_50705_4 branch #000004 normal 1\n',
#  'gi|1334822255|dbj|GBE17764.1| branch #000004 normal 1\n',
#  'Int298 branch #000004 normal 1\n',
#  'Int299 branch #000004 normal 1\n',
#  'Int300 branch #000004 normal 1\n',
#  'gi|1572540205|emb|VDD89171.1| branch #000004 normal 1\n',
#  'Int301 branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620106.270.0.1-0.22_1669_19 branch #000004 normal 1\n',
#  'TARA_037.SAMEA2619974.600.0.1-0.22_1115_42 branch #000004 normal 1\n',
#  'RBG_16_Archaea_50_20_RBG_16_scaffold_16389_9 branch #000004 normal 1\n',
#  'gi|974127776|gb|KUO42335.1| branch #000004 normal 1\n',
#  'Int302 branch #010005 normal 1\n',
#  'Int303 branch #000004 normal 1\n',
#  'Int304 branch #000004 normal 1\n',
#  'rifcsplowo2_01_scaffold_39879_1 branch #000004 normal 1\n',
#  'Int305 branch #000004 normal 1\n',
#  'gi|1572539548|emb|VDD88843.1| branch #000004 normal 1\n',
#  'RBG_13_scaffold_9498_7 branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620106.270.0.1-0.22_47_57 branch #000004 normal 1\n',
#  'Int306 branch #000004 normal 1\n',
#  'Int307 branch #000004 normal 1\n',
#  'Int308 branch #000004 normal 1\n',
#  'Int309 branch #000004 normal 1\n',
#  'gi|1281986543|ref|WP_100346025.1| branch #000004 normal 1\n',
#  'gi|1407184650|ref|WP_111090721.1| branch #000004 normal 1\n',
#  'gi|1391646159|ref|WP_109472021.1| branch #000004 normal 1\n',
#  'Int310 branch #000004 normal 1\n',
#  'gi|1344374241|ref|WP_104133976.1| branch #000004 normal 1\n',
#  'Int311 branch #000004 normal 1\n',
#  'Int312 branch #000004 normal 1\n',
#  'Int313 branch #000004 normal 1\n',
#  'Int314 branch #000004 normal 1\n',
#  'Int315 branch #000004 normal 1\n',
#  'Int316 branch #010005 normal 1\n',
#  'gi|1276444090|gb|PIO06052.1| branch #000004 normal 1\n',
#  'Int317 branch #000004 normal 1\n',
#  'Int318 branch #000004 normal 1\n',
#  'RBG_16_Chloroflexi_54_18_RBG_16_scaffold_1503_37 branch #000004 normal 1\n',
#  'Int319 branch #000004 normal 1\n',
#  'Int320 branch #000004 normal 1\n',
#  'Int321 branch #000004 normal 1\n',
#  'Int322 branch #010005 normal 1\n',
#  'Int323 branch #000004 normal 1\n',
#  'Int324 branch #000004 normal 1\n',
#  'Int325 branch #000004 normal 1\n',
#  'Int326 branch #000004 normal 1\n',
#  'Int327 branch #000004 normal 1\n',
#  'UBA3081contig_986_14 branch #000004 normal 1\n',
#  'Int328 branch #000004 normal 1\n',
#  'gwf2_scaffold_10625_13 branch #000004 normal 1\n',
#  'Int329 branch #000004 normal 1\n',
#  'gi|1277868389|gb|PIU76120.1| branch #000004 normal 1\n',
#  'UBA284contig_56696_5 branch #000004 normal 1\n',
#  'gi|1490911425|gb|RLE42410.1| branch #000004 normal 1\n',
#  'Int330 branch #000004 normal 1\n',
#  'Int331 branch #000004 normal 1\n',
#  'Int332 branch #000004 normal 1\n',
#  'gi|1572540139|emb|VDD89124.1| branch #000004 normal 1\n',
#  'gi|1572539386|emb|VDD88718.1| branch #000004 normal 1\n',
#  'RBG_13_Archaea_46_16b_RBG_13_scaffold_4070_13 branch #000004 normal 1\n',
#  'gi|1572540287|emb|VDD89238.1| branch #000004 normal 1\n',
#  'Int333 branch #000004 normal 1\n',
#  'Int334 branch #000004 normal 1\n',
#  'Int335 branch #000004 normal 1\n',
#  'Int336 branch #010005 normal 1\n',
#  'Int337 branch #000004 normal 1\n',
#  'Int338 branch #000004 normal 1\n',
#  'Int339 branch #000004 normal 1\n',
#  'Int340 branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620106.270.0.1-0.22_1013_16 branch #000004 normal 1\n',
#  'gi|1572539552|emb|VDD88845.1| branch #000004 normal 1\n',
#  'Int341 branch #000004 normal 1\n',
#  'Int342 branch #000004 normal 1\n',
#  'imgVR_3300017967_Ga0181590_10000756_38_PHAGE branch #000004 normal 1\n',
#  'Int343 branch #000004 normal 1\n',
#  'Int344 branch #000004 normal 1\n',
#  'Int345 branch #000004 normal 1\n',
#  'Int346 branch #000004 normal 1\n',
#  'Int347 branch #000004 normal 1\n',
#  'gi|1088817623|emb|SEB66243.1| branch #000004 normal 1\n',
#  'gi|1344376352|ref|WP_104136087.1| branch #000004 normal 1\n',
#  'gi|786030041|ref|WP_045731095.1| branch #000004 normal 1\n',
#  'gi|1604061387|ref|WP_134512914.1| branch #000004 normal 1\n',
#  'Int348 branch #000004 normal 1\n',
#  'gi|1223495427|ref|WP_091532692.1| branch #000004 normal 1\n',
#  'Int349 branch #000004 normal 1\n',
#  'Int350 branch #000004 normal 1\n',
#  'Int351 branch #000004 normal 1\n',
#  'Int352 branch #000004 normal 1\n',
#  'Int353 branch #000004 normal 1\n',
#  'Int354 branch #000004 normal 1\n',
#  'Int355 branch #000004 normal 1\n',
#  'Int356 branch #010005 normal 1\n',
#  'gi|1572540243|emb|VDD89203.1| branch #000004 normal 1\n',
#  'Int357 branch #000004 normal 1\n',
#  'Int358 branch #000004 normal 1\n',
#  '14_1009_16_20cm_scaffold_137301_2 branch #000004 normal 1\n',
#  'Int359 branch #000004 normal 1\n',
#  'Int360 branch #000004 normal 1\n',
#  'gi|985658392|gb|KXA90802.1| branch #000004 normal 1\n',
#  'gi|494110251|ref|WP_007051034.1| branch #000004 normal 1\n',
#  'gi|1469234453|ref|WP_117603172.1| branch #000004 normal 1\n',
#  'Int361 branch #000004 normal 1\n',
#  'Int362 branch #000004 normal 1\n',
#  'Int363 branch #010005 normal 1\n',
#  'Int364 branch #000004 normal 1\n',
#  'Int365 branch #000004 normal 1\n',
#  'gi|502513427|ref|WP_012809551.1| branch #000004 normal 1\n',
#  'Int366 branch #000004 normal 1\n',
#  'TARA_034.SAMEA2619907.60.0.22-1.6_1013533_52 branch #000004 normal 1\n',
#  'Int367 branch #000004 normal 1\n',
#  'Int368 branch #000004 normal 1\n',
#  'Int369 branch #000004 normal 1\n',
#  'Int370 branch #000004 normal 1\n',
#  'Int371 branch #000004 normal 1\n',
#  'gi|1572539530|emb|VDD88826.1| branch #000004 normal 1\n',
#  'Int372 branch #000004 normal 1\n',
#  'gi|1572540191|emb|VDD89164.1| branch #000004 normal 1\n',
#  'Int373 branch #000004 normal 1\n',
#  'gi|1572539955|emb|VDD88985.1| branch #000004 normal 1\n',
#  'gi|1491349521|gb|RLJ07768.1| branch #000004 normal 1\n',
#  'gi|1490926563|gb|RLE54831.1| branch #000004 normal 1\n',
#  'gi|1007508462|gb|KYH36691.1| branch #000004 normal 1\n',
#  'TARA_137.SAMEA2623314.375.0.22-3_757649_5 branch #000004 normal 1\n',
#  'gi|1572539921|emb|VDD88960.1| branch #000004 normal 1\n',
#  'gi|1572539700|emb|VDD88952.1| branch #000004 normal 1\n',
#  'Int374 branch #000004 normal 1\n',
#  'CG23_combo_of_CG0609_8_20_14_all_150_scaffold_26480_3 branch #000004 normal 1\n',
#  'gi|1572539979|emb|VDD89007.1| branch #000004 normal 1\n',
#  'gi|1231966352|gb|OYT29571.1| branch #000004 normal 1\n',
#  'Int375 branch #000004 normal 1\n',
#  'Int376 branch #010005 normal 1\n',
#  'Int377 branch #000004 normal 1\n',
#  'Int378 branch #000004 normal 1\n',
#  'Int379 branch #000004 normal 1\n',
#  'ncbi_ASMR01000001.1_43 branch #000004 normal 1\n',
#  'Int380 branch #000004 normal 1\n',
#  'Int381 branch #000004 normal 1\n',
#  'Int382 branch #000004 normal 1\n',
#  'gi|1572540193|emb|VDD89165.1| branch #000004 normal 1\n',
#  'Int383 branch #000004 normal 1\n',
#  'Int384 branch #000004 normal 1\n',
#  'Int385 branch #000004 normal 1\n',
#  'Int386 branch #000004 normal 1\n',
#  'Int387 branch #000004 normal 1\n',
#  'Int388 branch #000004 normal 1\n',
#  'Int389 branch #000004 normal 1\n',
#  'Int390 branch #000004 normal 1\n',
#  'Int391 branch #000004 normal 1\n',
#  'imgVR_3300006484_Ga0070744_10000432_2_PHAGE branch #000004 normal 1\n',
#  'Int392 branch #000004 normal 1\n',
#  'TARA_152.SAMEA2623919.25.0.22-3_2692249_4 branch #000004 normal 1\n',
#  'rifcsphigho2_12_scaffold_162_94_PHAGE branch #000004 normal 1\n',
#  'imgVR_3300013093_Ga0164296_1006299_14_PHAGE branch #000004 normal 1\n',
#  'Int393 branch #000004 normal 1\n',
#  'gi|1481029771|ref|WP_119659291.1| branch #000004 normal 1\n',
#  'gi|1477167632|ref|WP_119076514.1| branch #000004 normal 1\n',
#  'gi|1057398051|ref|WP_068752280.1| branch #000004 normal 1\n',
#  'Int394 branch #000004 normal 1\n',
#  'gi|1579045389|ref|WP_130387344.1| branch #000004 normal 1\n',
#  'gi|1352693617|ref|WP_104782455.1| branch #000004 normal 1\n',
#  'Int395 branch #000004 normal 1\n',
#  'Int396 branch #000004 normal 1\n',
#  'Int397 branch #000004 normal 1\n',
#  'Int398 branch #000004 normal 1\n',
#  'Int399 branch #000004 normal 1\n',
#  'Int400 branch #000004 normal 1\n',
#  'Int401 branch #000004 normal 1\n',
#  'Int402 branch #000004 normal 1\n',
#  'RIFCSPHIGHO2_02_FULL_CP_44_16_rifcsphigho2_02_scaffold_1846_14 branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620097.270.0.22-1.6_1443582_4 branch #000004 normal 1\n',
#  'Int403 branch #010005 normal 1\n',
#  'Int404 branch #000004 normal 1\n',
#  'gi|1572539632|emb|VDD88902.1| branch #000004 normal 1\n',
#  'gi|1572541063|emb|VDS11158.1| branch #000004 normal 1\n',
#  'gi|251771702|gb|EES52277.1| branch #000004 normal 1\n',
#  'gi|504263518|ref|WP_014450620.1| branch #000004 normal 1\n',
#  'Int405 branch #000004 normal 1\n',
#  'gi|653620633|ref|WP_027630963.1| branch #000004 normal 1\n',
#  'Int406 branch #000004 normal 1\n',
#  'GWC2_Chloroflexi_73_18_gwc2_scaffold_12078_2 branch #000004 normal 1\n',
#  'cg1_0.2_scaffold_14140_c_5 branch #000004 normal 1\n',
#  'Int407 branch #000004 normal 1\n',
#  'gi|1084749338|gb|OGP91707.1| branch #000004 normal 1\n',
#  'GWC2_Chloroflexi_73_18_gwc2_scaffold_9051_15 branch #000004 normal 1\n',
#  'RBG_16_Chloroflexi_54_18_RBG_16_scaffold_1503_25 branch #000004 normal 1\n',
#  'Int408 branch #010005 normal 1\n',
#  'Int409 branch #000004 normal 1\n',
#  'Int410 branch #000004 normal 1\n',
#  'Int411 branch #000004 normal 1\n',
#  'gi|452993361|emb|CCQ95102.1| branch #000004 normal 1\n',
#  'Int412 branch #000004 normal 1\n',
#  'Int413 branch #000004 normal 1\n',
#  'gi|506264208|ref|WP_015783983.1| branch #000004 normal 1\n',
#  'Int414 branch #000004 normal 1\n',
#  'Int415 branch #000004 normal 1\n',
#  'Int416 branch #000004 normal 1\n',
#  'Int417 branch #000004 normal 1\n',
#  'Int418 branch #000004 normal 1\n',
#  'Int419 branch #000004 normal 1\n',
#  'gi|1310987739|ref|WP_101073508.1| branch #000004 normal 1\n',
#  'Int420 branch #000004 normal 1\n',
#  'Int421 branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620106.270.0.1-0.22_3514_9 branch #000004 normal 1\n',
#  'rifoxya2_sub10_scaffold_3412_1 branch #000004 normal 1\n',
#  'Int422 branch #000004 normal 1\n',
#  'gwe1_scaffold_5288_7 branch #000004 normal 1\n',
#  'TARA_037.SAMEA2619974.600.0.1-0.22_18879_4 branch #000004 normal 1\n',
#  'Int423 branch #000004 normal 1\n',
#  'gi|1538763214|ref|WP_125672064.1| branch #000004 normal 1\n',
#  'gi|1491154651|gb|RLG40594.1| branch #000004 normal 1\n',
#  'Int424 branch #010005 normal 1\n',
#  'Int425 branch #000004 normal 1\n',
#  'Int426 branch #000004 normal 1\n',
#  'Int427 branch #000004 normal 1\n',
#  'Int428 branch #000004 normal 1\n',
#  'Int429 branch #000004 normal 1\n',
#  'Int430 branch #000004 normal 1\n',
#  'gi|1572541073|emb|VDS11163.1| branch #000004 normal 1\n',
#  'Int431 branch #000004 normal 1\n',
#  'gi|1572541025|emb|VDS11139.1| branch #000004 normal 1\n',
#  'gi|1572539586|emb|VDD88872.1| branch #000004 normal 1\n',
#  'rifcsphigho2_01_scaffold_37456_9 branch #000004 normal 1\n',
#  'gi|1572539923|emb|VDD88961.1| branch #000004 normal 1\n',
#  'Int432 branch #000004 normal 1\n',
#  'Int433 branch #000004 normal 1\n',
#  'rifcsphigho2_01_scaffold_111818_5 branch #000004 normal 1\n',
#  'Int434 branch #000004 normal 1\n',
#  'Int435 branch #000004 normal 1\n',
#  'Int436 branch #000004 normal 1\n',
#  'Int437 branch #000004 normal 1\n',
#  'imgVR_3300013093_Ga0164296_1000036_79_PHAGE branch #000004 normal 1\n',
#  'Int438 branch #000004 normal 1\n',
#  'Int439 branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620106.270.0.1-0.22_9196_2 branch #000004 normal 1\n',
#  'Int440 branch #000004 normal 1\n',
#  'TARA_076.SAMEA2621232.800.0.22-3_247045_7 branch #000004 normal 1\n',
#  'Int441 branch #000004 normal 1\n',
#  'Int442 branch #000004 normal 1\n',
#  'Int443 branch #000004 normal 1\n',
#  'Int444 branch #000004 normal 1\n',
#  'TARA_048.SAMEA2620404.5.0.22-1.6_2468987_1 branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620081.25.0.22-1.6_1488684_5 branch #000004 normal 1\n',
#  'imgVR_3300009164_Ga0114975_10000049_44_PHAGE branch #000004 normal 1\n',
#  'imgVR_3300002835_B570J40625_100002082_7_PHAGE branch #000004 normal 1\n',
#  'imgVR_3300006129_Ga0007834_1000020_33_PHAGE branch #000004 normal 1\n',
#  'Int445 branch #000004 normal 1\n',
#  'gi|1518444468|ref|WP_123305102.1| branch #000004 normal 1\n',
#  'gi|1316575601|ref|WP_101307147.1| branch #000004 normal 1\n',
#  'gi|1113335527|gb|OJV99781.1| branch #000004 normal 1\n',
#  'Int446 branch #000004 normal 1\n',
#  'Int447 branch #000004 normal 1\n',
#  'Int448 branch #000004 normal 1\n',
#  'Int449 branch #000004 normal 1\n',
#  'Int450 branch #000004 normal 1\n',
#  'Int451 branch #000004 normal 1\n',
#  'Int452 branch #000004 normal 1\n',
#  'gi|1482751988|ref|WP_119803251.1| branch #000004 normal 1\n',
#  'gi|1604915110|ref|WP_134702721.1| branch #000004 normal 1\n',
#  'Int453 branch #000004 normal 1\n',
#  'Int454 branch #000004 normal 1\n',
#  'gi|931449328|gb|KPK33274.1| branch #000004 normal 1\n',
#  'gi|1221597211|ref|WP_089728739.1| branch #000004 normal 1\n',
#  'gi|1165580525|ref|WP_079909251.1| branch #000004 normal 1\n',
#  'gi|1562212157|ref|WP_128657652.1| branch #000004 normal 1\n',
#  'Int455 branch #010005 normal 1\n',
#  'Int456 branch #000004 normal 1\n',
#  'gi|1277118558|gb|PIR20953.1| branch #000004 normal 1\n',
#  'RIFCSPLOWO2_02_FULL_Deltaproteobacteria_46_8_rifcsplowo2_02_scaffold_32024_19 branch #000004 normal 1\n',
#  'gi|1424203878|ref|WP_112482113.1| branch #000004 normal 1\n',
#  'Int457 branch #000004 normal 1\n',
#  'Int458 branch #000004 normal 1\n',
#  'gi|258553509|gb|ACV76451.1| branch #000004 normal 1\n',
#  'RIFOXYA2_FULL_CP_40_8_rifoxya2_full_scaffold_343_36 branch #000004 normal 1\n',
#  'cg1_0.2_scaffold_2874_c_10 branch #000004 normal 1\n',
#  'gi|1101991533|ref|WP_071541488.1| branch #000004 normal 1\n',
#  'Int459 branch #010005 normal 1\n',
#  'gi|655300655|ref|WP_028709495.1| branch #000004 normal 1\n',
#  'Int460 branch #000004 normal 1\n',
#  'gi|494108724|ref|WP_007049508.1| branch #000004 normal 1\n',
#  'Int461 branch #000004 normal 1\n',
#  'Int462 branch #000004 normal 1\n',
#  'gi|1225796762|ref|WP_093794202.1| branch #000004 normal 1\n',
#  'gi|499565835|ref|WP_011246618.1| branch #000004 normal 1\n',
#  'Int463 branch #000004 normal 1\n',
#  'gi|495051644|ref|WP_007776480.1| branch #000004 normal 1\n',
#  'gi|504412873|ref|WP_014599975.1| branch #000004 normal 1\n',
#  'gi|427373683|gb|AFY57639.1| branch #000004 normal 1\n',
#  'Int464 branch #000004 normal 1\n',
#  'TARA_145.SAMEA2623627.5.0.22-3_1990852_5 branch #000004 normal 1\n',
#  'Int465 branch #000004 normal 1\n',
#  'gi|1273801806|gb|PIE90237.1| branch #000004 normal 1\n',
#  'gi|783325917|gb|KJU84282.1| branch #000004 normal 1\n',
#  'TARA_085.SAMEA2621551.790.0.22-3_1126191_1 branch #000004 normal 1\n',
#  'Int466 branch #000004 normal 1\n',
#  'gi|1498187833|gb|RMG43845.1| branch #000004 normal 1\n',
#  'Int467 branch #000004 normal 1\n',
#  'Int468 branch #000004 normal 1\n',
#  'gi|1442342389|ref|WP_114983720.1| branch #000004 normal 1\n',
#  'gi|1370917987|ref|WP_106572864.1| branch #000004 normal 1\n',
#  'Int469 branch #000004 normal 1\n',
#  'Int470 branch #000004 normal 1\n',
#  'Int471 branch #000004 normal 1\n',
#  'Int472 branch #000004 normal 1\n',
#  'RBG_13_scaffold_565_33 branch #000004 normal 1\n',
#  'gi|1572539462|emb|VDD88772.1| branch #000004 normal 1\n',
#  'gi|1572539378|emb|VDD88708.1| branch #000004 normal 1\n',
#  'Int473 branch #010005 normal 1\n',
#  'gi|1491016538|gb|RLF28510.1| branch #000004 normal 1\n',
#  'gi|1491317414|gb|RLI80075.1| branch #000004 normal 1\n',
#  'Int474 branch #000004 normal 1\n',
#  'gi|1491080228|gb|RLF78506.1| branch #000004 normal 1\n',
#  'gi|1491297478|gb|RLI62811.1| branch #000004 normal 1\n',
#  'Int475 branch #000004 normal 1\n',
#  'Int476 branch #000004 normal 1\n',
#  'Int477 branch #000004 normal 1\n',
#  'gi|397681691|gb|AFO56068.1| branch #000004 normal 1\n',
#  'Int478 branch #000004 normal 1\n',
#  'gi|985668346|gb|KXA99463.1| branch #000004 normal 1\n',
#  'gi|1600022668|gb|TES94876.1| branch #000004 normal 1\n',
#  'Int479 branch #000004 normal 1\n',
#  'Int480 branch #000004 normal 1\n',
#  'Int481 branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620106.270.0.1-0.22_378_10 branch #000004 normal 1\n',
#  'Int482 branch #000004 normal 1\n',
#  'gi|1572539346|emb|VDD88676.1| branch #000004 normal 1\n',
#  'Int483 branch #000004 normal 1\n',
#  'Int484 branch #000004 normal 1\n',
#  'Int485 branch #000004 normal 1\n',
#  'imgVR_3300005683_Ga0074432_100043_78_PHAGE branch #000004 normal 1\n',
#  'Int486 branch #000004 normal 1\n',
#  'TARA_041.SAMEA2620217.60.0.22-1.6_1670635_17 branch #000004 normal 1\n',
#  'TARA_034.SAMEA2619923.60.0-0.22_219_19 branch #000004 normal 1\n',
#  'imgVR_3300009155_Ga0114968_10000900_19_PHAGE branch #000004 normal 1\n',
#  'Int487 branch #000004 normal 1\n',
#  'gwa2_scaffold_24083_5 branch #000004 normal 1\n',
#  'TARA_151.SAMEA2623850.5.0.22-3_2451760_4 branch #000004 normal 1\n',
#  'imgVR_3300009058_Ga0102854_1000016_27_PHAGE branch #000004 normal 1\n',
#  'Int488 branch #000004 normal 1\n',
#  'Int489 branch #000004 normal 1\n',
#  'TARA_066.SAMEA2620967.30.0-0.22_543152_1 branch #000004 normal 1\n',
#  'imgVR_3300018790_Ga0187842_1000009_46_PHAGE branch #000004 normal 1\n',
#  'Int490 branch #000004 normal 1\n',
#  'TARA_125.SAMEA2622823.5.0.45-0.8_146852_3 branch #000004 normal 1\n',
#  'Int491 branch #000004 normal 1\n',
#  'PH2015_07_scaffold_0_448_PHAGE branch #000004 normal 1\n',
#  'Int492 branch #000004 normal 1\n',
#  'Int493 branch #000004 normal 1\n',
#  'imgVR_3300000117_DelMOWin2010_c10001624_5_PHAGE branch #000004 normal 1\n',
#  'imgVR_3300000439_TBL_comb48_EPIDRAFT_1000912_4_PHAGE branch #000004 normal 1\n',
#  'imgVR_3300000553_TBL_comb47_HYPODRAFT_10006500_13_PHAGE branch #000004 normal 1\n',
#  'Int494 branch #000004 normal 1\n',
#  'gi|1598227081|ref|WP_133867424.1| branch #000004 normal 1\n',
#  'Int495 branch #000004 normal 1\n',
#  'Int496 branch #000004 normal 1\n',
#  'Int497 branch #000004 normal 1\n',
#  'Int498 branch #000004 normal 1\n',
#  'gi|652867120|ref|WP_027135992.1| branch #000004 normal 1\n',
#  'Int499 branch #000004 normal 1\n',
#  'gi|550363837|ref|WP_022613754.1| branch #000004 normal 1\n',
#  'gi|1293243027|ref|WP_100636364.1| branch #000004 normal 1\n',
#  'TARA_032.SAMEA2619840.80.0.22-1.6_1922061_3 branch #000004 normal 1\n',
#  'gi|501796652|ref|WP_012641545.1| branch #000004 normal 1\n',
#  'TARA_034.SAMEA2619907.60.0.22-1.6_3121312_10 branch #000004 normal 1\n',
#  'Int500 branch #000004 normal 1\n',
#  'gi|1271522479|ref|WP_099304159.1| branch #000004 normal 1\n',
#  'gi|1268687694|ref|WP_098980384.1| branch #000004 normal 1\n',
#  'gi|1282047063|ref|WP_100405522.1| branch #000004 normal 1\n',
#  'Int501 branch #000004 normal 1\n',
#  'gi|493839801|ref|WP_006786951.1| branch #000004 normal 1\n',
#  'Int502 branch #010005 normal 1\n',
#  'gi|1490513022|gb|RLB33671.1| branch #000004 normal 1\n',
#  'Int503 branch #000004 normal 1\n',
#  'gi|225045473|gb|EEG55719.1| branch #000004 normal 1\n',
#  'gi|503545175|ref|WP_013779251.1| branch #000004 normal 1\n',
#  'gi|902564321|ref|WP_049620396.1| branch #000004 normal 1\n',
#  'gi|655300228|ref|WP_028709069.1| branch #000004 normal 1\n',
#  'Int504 branch #010005 normal 1\n',
#  'Int505 branch #000004 normal 1\n',
#  'gi|1486542681|ref|WP_120058448.1| branch #000004 normal 1\n',
#  'gi|740491944|ref|WP_038322855.1| branch #000004 normal 1\n',
#  'gi|1223798845|ref|WP_091832592.1| branch #000004 normal 1\n',
#  'gi|1488321905|ref|WP_120768880.1| branch #000004 normal 1\n',
#  'Int506 branch #000004 normal 1\n',
#  'Int507 branch #000004 normal 1\n',
#  'Int508 branch #000004 normal 1\n',
#  'Int509 branch #000004 normal 1\n',
#  'gi|504774682|ref|WP_014961784.1| branch #000004 normal 1\n',
#  'gi|339834681|gb|EGQ62427.1| branch #000004 normal 1\n',
#  'gi|1584756265|gb|TBR23247.1| branch #000004 normal 1\n',
#  'Int510 branch #000004 normal 1\n',
#  'Int511 branch #000004 normal 1\n',
#  'Int512 branch #000004 normal 1\n',
#  'Int513 branch #000004 normal 1\n',
#  'Int514 branch #000004 normal 1\n',
#  'Int515 branch #000004 normal 1\n',
#  'CG_201509_scaffold_5489_2 branch #000004 normal 1\n',
#  'Int516 branch #000004 normal 1\n',
#  'Int517 branch #000004 normal 1\n',
#  'Int518 branch #000004 normal 1\n',
#  'Int519 branch #000004 normal 1\n',
#  'Int520 branch #000004 normal 1\n',
#  'Int521 branch #000004 normal 1\n',
#  'RIFCSPLOWO2_02_FULL_GWA2_OP11_40_10_rifcsplowo2_02_scaffold_595_29 branch #000004 normal 1\n',
#  '16ft_4_scaffold_46755_1 branch #000004 normal 1\n',
#  'Int522 branch #010005 normal 1\n',
#  'Int523 branch #000004 normal 1\n',
#  'gi|1491315932|gb|RLI78728.1| branch #000004 normal 1\n',
#  'gi|505404440|ref|WP_015591542.1| branch #000004 normal 1\n',
#  'Int524 branch #000004 normal 1\n',
#  'Int525 branch #000004 normal 1\n',
#  'Int526 branch #000004 normal 1\n',
#  'gi|1572540005|emb|VDD89031.1| branch #000004 normal 1\n',
#  'CAI49476_Natronomonas_pharaonis_DSM_2160_II_REF branch #000004 normal 1\n',
#  'gi|910243764|ref|WP_050048430.1| branch #000004 normal 1\n',
#  'gi|1482765045|ref|WP_119815746.1| branch #000004 normal 1\n',
#  'gi|1124507462|ref|WP_074791909.1| branch #000004 normal 1\n',
#  'gi|1572540249|emb|VDD89207.1| branch #000004 normal 1\n',
#  'gi|1278500188|gb|PJA22022.1| branch #000004 normal 1\n',
#  'Int527 branch #000004 normal 1\n',
#  'gi|1572541111|emb|VDS11182.1| branch #000004 normal 1\n',
#  'gi|1572539356|emb|VDD88684.1| branch #000004 normal 1\n',
#  'Int528 branch #000004 normal 1\n',
#  'gi|1572539376|emb|VDD88707.1| branch #000004 normal 1\n',
#  'rifcsphigho2_01_scaffold_21619_3 branch #000004 normal 1\n',
#  'gi|1572539492|emb|VDD88791.1| branch #000004 normal 1\n',
#  'Int529 branch #000004 normal 1\n',
#  'Int530 branch #000004 normal 1\n',
#  'Int531 branch #000004 normal 1\n',
#  'Int532 branch #000004 normal 1\n',
#  'Int533 branch #000004 normal 1\n',
#  'imgVR_3300009182_Ga0114959_10006311_8_PHAGE branch #000004 normal 1\n',
#  'Int534 branch #000004 normal 1\n',
#  'TARA_123.SAMEA2622736.150.0.1-0.22_389732_5 branch #000004 normal 1\n',
#  'TARA_032.SAMEA2619838.5.0-0.22_336_6 branch #000004 normal 1\n',
#  'TARA_067.SAMEA2620979.5.0.22-0.45_264655_4 branch #000004 normal 1\n',
#  'TARA_076.SAMEA2621203.5.0.22-0.45_2184309_5 branch #000004 normal 1\n',
#  'TARA_125.SAMEA2622822.5.0.22-0.45_1408834_6 branch #000004 normal 1\n',
#  'TARA_122.SAMEA2622656.5.0.1-0.22_392076_2 branch #000004 normal 1\n',
#  'TARA_067.SAMEA2620979.5.0.22-0.45_599637_11 branch #000004 normal 1\n',
#  'Int535 branch #000004 normal 1\n',
#  'Int536 branch #000004 normal 1\n',
#  'Int537 branch #000004 normal 1\n',
#  'TARA_039.SAMEA2620106.270.0.1-0.22_4721_4 branch #000004 normal 1\n',
#  'Int538 branch #000004 normal 1\n',
#  'imgVR_3300012953_Ga0163179_10002555_5_PHAGE branch #000004 normal 1\n',
#  'Int539 branch #000004 normal 1\n',
#  'Int540 branch #000004 normal 1\n',
#  'gi|1565948406|ref|WP_129115542.1| branch #000004 normal 1\n',
#  'gi|499126410|ref|WP_010855254.1| branch #000004 normal 1\n',
#  'Int541 branch #000004 normal 1\n',
#  'Int542 branch #000004 normal 1\n',
#  'Int543 branch #000004 normal 1\n',
#  'gi|563911827|ref|WP_023807801.1| branch #000004 normal 1\n',
#  'Int544 branch #000004 normal 1\n',
#  'Int545 branch #000004 normal 1\n',
#  'gi|806811508|ref|WP_046170552.1| branch #000004 normal 1\n',
#  ...]

# %%
[x for x in lines if 'gi|518331021|ref|WP_019501228.1| ' in x]
[x for x in lines if 'gi|518331021|ref|WP_019501228.1| ' in x]
# Out:
# ['gi|518331021|ref|WP_019501228.1| branch #e34e65 normal 1\n']

# %%
#measurements.loc[[x.name for x in [x for x in t.traverse() if x.name == 'I85'][0].get_leaves()]]
#mp.colors.to_hex(mg([x for x in t.traverse() if x.name == 'Int29'][0].frac_measured*256))
mp.colors.to_hex(mg(pd.np.floor([x for x in t.traverse() if x.name == 'Int29'][0].frac_measured*256)))
#mp.colors.to_hex(mg(3.65))
#[x for x in t.traverse() if x.name == 'Int29'][0].frac_measured*256
#mg(3.65)
#mp.colors.to_hex(mg(int([x for x in t.traverse() if x.name == 'Int29'][0].frac_measured*256)))
int([x for x in t.traverse() if x.name == 'gi|518331021|ref|WP_019501228.1|'][0].frac_measured/max_frac*256)
l = [x for x in t.traverse() if x.name == 'Int11'][0]
[[x.name,x.num_measured] for x in l.get_leaves()]
# Out:
# [['PH2015_07_scaffold_0_448_PHAGE', 0],
#  ['TARA_039.SAMEA2620106.270.0.1-0.22_4721_4', 0],
#  ['TARA_042.SAMEA2620230.5.0.22-1.6_957446_9', 0],
#  ['TARA_052.SAMEA2620542.5.0.22-1.6_2455572_5', 0],
#  ['imgVR_3300012953_Ga0163179_10002555_5_PHAGE', 0],
#  ['TARA_042.SAMEA2620230.5.0.22-1.6_61010_2', 0],
#  ['TARA_009.SAMEA2619548.55.0.22-1.6_578978_3', 0],
#  ['imgVR_3300000117_DelMOWin2010_c10001624_5_PHAGE', 0],
#  ['TARA_048.SAMEA2620404.5.0.22-1.6_2468987_1', 0],
#  ['TARA_039.SAMEA2620081.25.0.22-1.6_1488684_5', 0],
#  ['imgVR_3300006484_Ga0070744_10000432_2_PHAGE', 0],
#  ['imgVR_3300009164_Ga0114975_10000049_44_PHAGE', 0],
#  ['imgVR_3300002835_B570J40625_100002082_7_PHAGE', 0],
#  ['TARA_152.SAMEA2623919.25.0.22-3_2692249_4', 0],
#  ['rifcsphigho2_12_scaffold_162_94_PHAGE', 0],
#  ['imgVR_3300013093_Ga0164296_1006299_14_PHAGE', 0],
#  ['imgVR_3300006129_Ga0007834_1000020_33_PHAGE', 0],
#  ['imgVR_3300000439_TBL_comb48_EPIDRAFT_1000912_4_PHAGE', 0],
#  ['imgVR_3300000553_TBL_comb47_HYPODRAFT_10006500_13_PHAGE', 0]]

# %%
for leaf in t.traverse():
    leaf.add_feature('frac_measured',sum([measurements.loc[x.name] for x in leaf.get_leaves() if x.name in measurements.index]))
    line = leaf.name + ' ' + 'branch ' + mp.colors.to_hex(mg(leaf.frac_measured*256), keep_alpha=False) + ' normal ' + 5 +'\n'
    lines.append(line)
#pd.Series([x.name for x in t.get_leaves()]).isin(uc2.ID)

# %%
with open('../data/colors_styles_template.txt','r') as file:
    with open('../output_itai/01_70p_tree/kinetic_branch_colors.txt', "w") as f1:
        for row in file:
            f1.write(row)
        for line in lines:
            f1.write(line)
        file.close()
        f1.close()

# %%
ts = TreeStyle()
ts.mode = "c"
ts.arc_start = -120 # 0 degrees = 3 o'clock
ts.arc_span = 360
t.show(tree_style=ts)

# %%
t
# Out:
# Tree node 'I0' (-0x7fffffe0654290af)

# %%
t.write(format=1, outfile="../output_itai/01_70p_tree/new_tree.nw")

# %%
mg = cm.get_cmap('magma',lut=1)
#mg = cm.get_cmap('magma')
[256*x for x in mg(1)]


ns = NodeStyle()
    ns["fgcolor"] = colors[l.name]
    l.img_style = ns
# Out:
# [0.578048, 0.33152, 4.692736, 256.0]

# %%
t = Tree('/home/yinonbaron/Downloads/40nFYGu0DZaYY90hWZr4mA_newick.txt',format=2)
# Out:
# ---------------------------------------------------------------------------
# NewickError                               Traceback (most recent call last)
# <ipython-input-43-b2e666462f1d> in <module>
# ----> 1 t = Tree('/home/yinonbaron/Downloads/40nFYGu0DZaYY90hWZr4mA_newick.txt',format=2)
#
# /usr/local/lib/python3.7/dist-packages/ete3/coretype/tree.py in __init__(self, newick, format, dist, support, name, quoted_node_names)
#     209             self._dist = 0.0
#     210             read_newick(newick, root_node = self, format=format,
# --> 211                         quoted_names=quoted_node_names)
#     212
#     213
#
# /usr/local/lib/python3.7/dist-packages/ete3/parser/newick.py in read_newick(newick, root_node, format, quoted_names)
#     249             raise NewickError('Unexisting tree file or Malformed newick tree structure.')
#     250         else:
# --> 251             return _read_newick_from_string(nw, root_node, matcher, format, quoted_names)
#     252
#     253     else:
#
# /usr/local/lib/python3.7/dist-packages/ete3/parser/newick.py in _read_newick_from_string(nw, root_node, matcher, formatcode, quoted_names)
#     324                     closing_internal =  closing_internal.rstrip(";")
#     325                     # read internal node data and go up one level
# --> 326                     _read_node_data(closing_internal, current_parent, "internal", matcher, formatcode)
#     327                     current_parent = current_parent.up
#     328
#
# /usr/local/lib/python3.7/dist-packages/ete3/parser/newick.py in _read_node_data(subnw, current_node, node_type, matcher, formatcode)
#     428             _parse_extra_features(node, data[2])
#     429     else:
# --> 430         raise NewickError("Unexpected newick format '%s' " %subnw[0:50])
#     431     return
#     432
#
# NewickError: Unexpected newick format ':0.01204999099537009018[28]'
# You may want to check other newick loading flags like 'format' or 'quoted_node_names'.
