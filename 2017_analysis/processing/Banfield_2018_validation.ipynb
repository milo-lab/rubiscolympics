# %%
import os, shutil
import pandas as pd
from Bio import SeqIO
import numpy as np
from Bio import AlignIO
from collections import Counter
from Bio import Seq

# %% [markdown]
# # 01 - merge fasta files and cluster sequences

# %%
sequences = []
for record in SeqIO.parse('../data/jaffe_et_al_2018_rubisco_superfamilies.faa', "fasta"):
    record.description = record.description.split(':')[0]
    record.id = record.id.split(':')[0]
    record.name = record.name.split(':')[0]
    sequences.append(record)
        
with open(r"../data/jaffe_et_al_2018_rubisco_superfamilies_clean.faa", "w") as output_handle:
    SeqIO.write(sequences, output_handle, "fasta")

# %%
#!cat ../data/milo_synthetized_rubisco.faa ../data/RuBisCO.300-700.faa ../data/flamholz_et_al_2019_kinetically_characterized.faa ../data/erb_et_al_2012_rubisco_superfamilies.faa > ../data/merged_data.faa
# !cat ../data/milo_synthetized_rubisco.faa ../data/RuBisCO.300-700.faa ../data/flamholz_et_al_2019_kinetically_characterized.faa ../data/jaffe_et_al_2018_rubisco_superfamilies_clean.faa > ../data/merged_data.faa

# %%
sequences = []
for record in SeqIO.parse('../data/merged_data.faa', "fasta"):
    record.seq = record.seq.split('*')[0]
    sequences.append(record)
        
with open(r"../data/merged_data.faa", "w") as output_handle:
    SeqIO.write(sequences, output_handle, "fasta")

# %%
fasta = r"../data/merged_data.faa"

# Linux - Change bin
uclust = "../bin/usearch11.0.667_i86linux32 -cluster_fast %s -id 0.7 -uc ../output/01_uclust_all_0.7.uc" %fasta

# Windows
#uclust = r"..\bin\usearch11.0.667_win32.exe -cluster_fast %s -id 0.7 -uc ..\output\01_uclust_all_0.7.uc" %fasta

# %%
os.system(uclust)
# Out:
# 0

# %%
header = ['Type','Cluster','Size','%Id','Strand','Qlo','Tlo','Alignment','Query','Target']
uclust = pd.read_csv(r"../output/01_uclust_all_0.7.uc", sep='\t', names=header, index_col=False)
centroids = uclust[uclust['Type']=='C']
c_list = centroids.iloc[:,8].values
c_list = [c.split(" ")[0] for c in c_list]

sequences = []
for record in SeqIO.parse(fasta, "fasta"):
    if record.id in c_list:
        sequences.append(record)

seq2 = []
seq3 = []
for i,record in enumerate(sequences):
    if not record.id in seq2: 
        seq2.append(record.id)
        seq3.append(record)

        
with open(r"../output/01_uclust_all_0.7.faa", "w") as output_handle:
    SeqIO.write(seq3, output_handle, "fasta")

uclust.to_csv(r'../output/01_uclust_all_0.7.csv',index=False)

# %% [markdown]
# # 02 - Create multiple sequence alignment

# %%
# !../bin/mafft-linux64/mafft.bat ../output/01_uclust_all_0.7.faa > ../output/02_uclust_all_0.7.aln
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#
# There are 57 ambiguous characters.
#   601 / 601
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   590 / 601
# done.
#
# Progressive alignment 1/2...
# STEP   414 / 600
# Reallocating..done. *alloclen = 2430
# STEP   501 / 600  h
# Reallocating..done. *alloclen = 3611
#
# done.
#
# Making a distance matrix from msa..
#   500 / 601
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   590 / 601
# done.
#
# Progressive alignment 2/2...
# STEP   401 / 600
# Reallocating..done. *alloclen = 2482
# STEP   501 / 600
# Reallocating..done. *alloclen = 3519
#
# done.
#
# disttbfast (aa) Version 7.427
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.

# %% [markdown]
# # 03 - clean MSA to contain only positions with more than 5% coverage (based on Jaffe et al. 2018)

# %%
#aln = AlignIO.read('../output/02_uclust_all_0.7.aln',format='fasta')

aln = AlignIO.read('../data/jaffe_et_al_2018_rubisco_superfamilies.aln',format='fasta')
mask = []
for i in range(0,aln.get_alignment_length()):
    mask.append(Counter(aln[:,i])['-']/len(aln[:,i])<0.95)
    
np_aln = np.array(aln)
np_aln = np_aln[:,mask]

aln_faa = SeqIO.parse('../data/jaffe_et_al_2018_rubisco_superfamilies.aln',format='fasta')
sequences = []
for record,i in zip(aln_faa,range(0,len(aln))):
    record.seq = Seq.Seq("".join(np_aln[i,:]), Seq.Alphabet.SingleLetterAlphabet())
    f = record.id.split(":")[0]
    record.id = f
    sequences.append(record)
        
with open(r"../output/jaffe_et_al_2018_rubisco_superfamilies_trimmed.aln", "w") as output_handle:
    SeqIO.write(sequences, output_handle, "fasta")

# %%
# Status
#!curl -u yinonbaron:Mchcav11~ -H cipres-appkey:rubisco_phylogeny-49F87B124F3D429FBE12F95E4254DDEA https://cipresrest.sdsc.edu/cipresrest/v1/job/yinonbaron/NGBW-JOB-RAXMLHPC8_REST_XSEDE-3552B7E1CC8345EA97221BBD8C26649B
# Results
#!curl -u yinonbaron:Mchcav11~ -H cipres-appkey:rubisco_phylogeny-49F87B124F3D429FBE12F95E4254DDEA https://cipresrest.sdsc.edu/cipresrest/v1/job/yinonbaron/NGBW-JOB-RAXMLHPC8_REST_XSEDE-3552B7E1CC8345EA97221BBD8C26649B/output

# Download
#!curl -u yinonbaron:Mchcav11~ -H cipres-appkey:rubisco_phylogeny-49F87B124F3D429FBE12F95E4254DDEA https://cipresrest.sdsc.edu/cipresrest/v1/job/yinonbaron/NGBW-JOB-RAXMLHPC8_REST_XSEDE-3552B7E1CC8345EA97221BBD8C26649B/output/971441

#Most up to dat
# !curl -u yinonbaron:Mchcav11~ -H cipres-appkey:rubisco_phylogeny-49F87B124F3D429FBE12F95E4254DDEA https://cipresrest.sdsc.edu/cipresrest/v1/job/yinonbaron -F tool=RAXMLHPC8_REST_XSEDE  -F input.infile_=@../output/jaffe_et_al_2018_rubisco_superfamilies_trimmed.aln -F metadata.statusEmail=true -F vparam.datatype_=protein -F vparam.runtime_=160 -F  vparam.select_analysis_=fa -F vparam.choose_bootstrap_=x -F vparam.printbrlength_=1
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <jobstatus>
#     <selfUri>
#         <url>https://cipresrest.sdsc.edu/cipresrest/v1/job/yinonbaron/NGBW-JOB-RAXMLHPC8_REST_XSEDE-21903929C1EA4B66B87B7C51CD2FB68B</url>
#         <rel>jobstatus</rel>
#         <title>NGBW-JOB-RAXMLHPC8_REST_XSEDE-21903929C1EA4B66B87B7C51CD2FB68B</title>
#     </selfUri>
#     <jobHandle>NGBW-JOB-RAXMLHPC8_REST_XSEDE-21903929C1EA4B66B87B7C51CD2FB68B</jobHandle>
#     <jobStage>QUEUE</jobStage>
#     <terminalStage>false</terminalStage>
#     <failed>false</failed>
#     <metadata>
#         <entry>
#             <key>statusEmail</key>
#             <value>true</value>
#         </entry>
#     </metadata>
#     <dateSubmitted>2019-04-07T05:19:29-07:00</dateSubmitted>
#     <resultsUri>
#         <url>https://cipresrest.sdsc.edu/cipresrest/v1/job/yinonbaron/NGBW-JOB-RAXMLHPC8_REST_XSEDE-21903929C1EA4B66B87B7C51CD2FB68B/output</url>
#         <rel>results</rel>
#         <title>Job Results</title>
#     </resultsUri>
#     <workingDirUri>
#         <url>https://cipresrest.sdsc.edu/cipresrest/v1/job/yinonbaron/NGBW-JOB-RAXMLHPC8_REST_XSEDE-21903929C1EA4B66B87B7C51CD2FB68B/workingdir</url>
#         <rel>workingdir</rel>
#         <title>Job Working Directory</title>
#     </workingDirUri>
#     <messages>
#         <message>
#             <timestamp>2019-04-07T05:19:29-07:00</timestamp>
#             <stage>QUEUE</stage>
#             <text>Added to run queue.</text>
#         </message>
#     </messages>
#     <minPollIntervalSeconds>60</minPollIntervalSeconds>
# </jobstatus>

# %%
# 04 - Create tree

# %%
# !../bin/FastTree -spr 4 -mlacc 2 -slownni ../output/03_uclust_all_0.7_trimmed.aln > ../output/04_uclust_all_0.7.nwk
# Out:
# FastTree Version 2.1.10 SSE3
# Alignment: ../output/03_uclust_all_0.7_trimmed.aln
# Amino acid distances: BLOSUM45 Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (4 rounds range 10) +ML-NNI opt-each=2
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Jones-Taylor-Thorton, CAT approximation with 20 rate categories
# Ignored unknown character B (seen 4 times)
# Ignored unknown character X (seen 41 times)
# Ignored unknown character Z (seen 4 times)
# Initial topology in 0.60 seconds
# Refining topology: 37 rounds ME-NNIs, 4 rounds ME-SPRs, 18 rounds ML-NNIs
# Total branch-length 158.296 after 7.28 sec
# ML-NNI round 1: LogLk = -341214.872 NNIs 108 max delta 16.87 Time 12.48
# Switched to using 20 rate categories (CAT approximation)
# Rate categories were divided by 1.307 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
# ML-NNI round 2: LogLk = -323350.811 NNIs 45 max delta 17.74 Time 19.77
# ML-NNI round 3: LogLk = -323289.919 NNIs 22 max delta 7.33 Time 25.32
# ML-NNI round 4: LogLk = -323242.321 NNIs 19 max delta 8.91 Time 30.85
# ML-NNI round 5: LogLk = -323162.026 NNIs 10 max delta 30.19 Time 36.41
# ML-NNI round 6: LogLk = -323124.977 NNIs 8 max delta 9.48 Time 42.05
# ML-NNI round 7: LogLk = -323104.348 NNIs 4 max delta 12.68 Time 47.66
# ML-NNI round 8: LogLk = -323100.905 NNIs 3 max delta 2.56 Time 53.18
# ML-NNI round 9: LogLk = -323100.609 NNIs 0 max delta 0.00 Time 58.69
# Turning off heuristics for final round of ML NNIs (converged)
# ML-NNI round 10: LogLk = -323100.603 NNIs 0 max delta 0.00 Time 64.21 (final)
# Optimize all lengths: LogLk = -323100.604 Time 65.18
# Total time: 68.55 seconds Unique: 601/601 Bad splits: 0/598

# %%
labels = pd.read_csv('../data/jaffe_et_al_2018_rubisco_types.csv')
labels
# Out:
#                                                     ID           Organism  \
# 0                2_Hydrogenovibrio_marinus_BAD1531_REF          reference
# 1       AAB41464_Aurantimonas_manganoxydans_SI85_I_REF          reference
# 2        ABA23512_Anabaena_variabilis_ATCC_29413_I_REF          reference
# 3       ABA56859_Nitrosococcus_oceani_ATCC_19707_I_REF          reference
# 4          Acidimicrobium_ferrooxidans_YP_00310876_REF          reference
# 5               Alkalilimnicola_ehrlichii_YP_74366_REF          reference
# 6               Allochromatium_vinosum_YP_00344469_REF          reference
# 7                        Azoarcus_sp_KH32C_BAL2711_REF          reference
# 8            Bradyrhizobium_sp_ORS_278_YP_00120434_REF          reference
# 9                 Burkholderia_xenovorans_YP_55288_REF          reference
# 10                Chondrophycus_papillosus_ABO3124_REF          reference
# 11              Cupriavidus_metallidurans_YP_58365_REF          reference
# 12                           Galdieria_Partita_1IW_REF          reference
# 13            Halorhodospira_halophila_YP_00100262_REF          reference
# 14                       Isoetes_savatieri_AAM3458_REF          reference
# 15                  NP_043654_Odontella_sinensis_I_REF          reference
# 16               Nitrobacter_hamburgensis_YP_57154_REF          reference
# 17                  Nitrococcus_mobilis_ZP_0112568_REF          reference
# 18                  Nitrosomonas_eutropha_YP_74703_REF          reference
# 19                      P00876_Nicotiana_tabacum_I_REF          reference
# 20                    Paracoccus_sp_TRP_ZP_0866487_REF          reference
# 21                             Picea_abies_CAA5320_REF          reference
# 22             Prochlorococcus_marinus_YP_00109080_REF          reference
# 23                           Pyropia_dentata_Q760S_REF          reference
# 24                 Q08051_Pleurochrysis_carterae_I_REF          reference
# 25         Q51856_Hydrogenophilus_thermoluteolus_I_REF          reference
# 26                   Q59613_Nitrobacter_vulgaris_I_REF          reference
# 27                Rhodobacter_sphaeroides_YP_35436_REF          reference
# 28           Rubrivivax_benzoatilyticus_ZP_0840404_REF          reference
# 29               Sinorhizobium_medicae_YP_00131266_REF          reference
# ..                                                 ...                ...
# 735   imgVR_3300009182_____Ga0114959_10000188_47_PHAGE     putative_phage
# 736    imgVR_3300009182_____Ga0114959_10006311_8_PHAGE     putative_phage
# 737  imgVR_3300009183_____Ga0114974_10000026_102_PHAGE     putative_phage
# 738  imgVR_3300010334_____Ga0136644_10000002_223_PHAGE     putative_phage
# 739    imgVR_3300012953_____Ga0163179_10002555_5_PHAGE     putative_phage
# 740    imgVR_3300012953_____Ga0163179_10002609_6_PHAGE     putative_phage
# 741    imgVR_3300013093_____Ga0164296_1000036_79_PHAGE     putative_phage
# 742    imgVR_3300013093_____Ga0164296_1001304_19_PHAGE     putative_phage
# 743    imgVR_3300013093_____Ga0164296_1006299_14_PHAGE     putative_phage
# 744   imgVR_3300013131_____Ga0172373_10003100_23_PHAGE     putative_phage
# 745   imgVR_3300013132_____Ga0172372_10011093_16_PHAGE     putative_phage
# 746    imgVR_3300017818_____Ga0181565_10006269_7_PHAGE     putative_phage
# 747   imgVR_3300017967_____Ga0181590_10000756_38_PHAGE     putative_phage
# 748   imgVR_3300017986_____Ga0181569_10001190_17_PHAGE     putative_phage
# 749   imgVR_3300017989_____Ga0180432_10000539_12_PHAGE     putative_phage
# 750    imgVR_3300018423_____Ga0181593_10013560_4_PHAGE     putative_phage
# 751    imgVR_3300018790_____Ga0187842_1000009_46_PHAGE     putative_phage
# 752              rifcsphigho2_12_scaffold_162_94_PHAGE     putative_phage
# 753                             RBG_13_scaffold_9498_7            unknown
# 754                    rifcsplowo2_01_scaffold_4908_46    Aenigmarchaeota
# 755            CG08_land_8_20_14_0.20_scaffold_15999_2  Gottesmanbacteria
# 756                           RBG_16_scaffold_32845_14      Micrarchaeota
# 757                           RBG_16_scaffold_41955_19      Micrarchaeota
# 758               RifSed_csp2_16ft_2_scaffold_590394_1      Micrarchaeota
# 759                                UBA93contig_1572_78      Micrarchaeota
# 760                               UBA96contig_21807_17      Micrarchaeota
# 761                                  mol3215fa040034_9      Micrarchaeota
# 762                  rifcsphigho2_01_scaffold_100504_5      Micrarchaeota
# 763                              ncbi_AWOG01000022.1_5      Nanoarchaeota
# 764                            LSDeep1_scaffold_289_96  Peregrinibacteria
#
#         type
# 0          I
# 1          I
# 2          I
# 3          I
# 4          I
# 5          I
# 6          I
# 7          I
# 8          I
# 9          I
# 10         I
# 11         I
# 12         I
# 13         I
# 14         I
# 15         I
# 16         I
# 17         I
# 18         I
# 19         I
# 20         I
# 21         I
# 22         I
# 23         I
# 24         I
# 25         I
# 26         I
# 27         I
# 28         I
# 29         I
# ..       ...
# 735   IVlike
# 736   IVlike
# 737   IVlike
# 738   IVlike
# 739   IVlike
# 740   IVlike
# 741   IVlike
# 742   IVlike
# 743   IVlike
# 744   IVlike
# 745   IVlike
# 746   IVlike
# 747   IVlike
# 748   IVlike
# 749   IVlike
# 750   IVlike
# 751   IVlike
# 752   IVlike
# 753   IVlike
# 754  unknown
# 755  unknown
# 756  unknown
# 757  unknown
# 758  unknown
# 759  unknown
# 760  unknown
# 761  unknown
# 762  unknown
# 763  unknown
# 764  unknown
#
# [765 rows x 3 columns]

# %%
labels = pd.read_csv('../data/jaffe_et_al_2018_rubisco_types.csv')
uclust_data = pd.read_csv('../output/01_uclust_all_0.7.csv')
uclust_data = uclust_data[uclust_data['Type'] !='S']
uclust_data.loc[uclust_data['Target'] == '*','Target'] = uclust_data.loc[uclust_data['Target'] == '*','Query']
uclust_data = uclust_data.merge(labels, left_on='Query', right_on='ID',how='left')
labeled_leaves = uclust_data[~pd.isna(uclust_data['type'])]
#labels[~labels['ID'].isin(uclust_data['ID'])]
#labels
#color_map = {'1': '#a0bc5d', '2': '#1d69d2', '3':'#ff0000','2_3':'#ffbf00'}
color_map = {'I': '#28B463', 'II': '#E74C3C', 'II/III':'#AF7AC5','IIIa':'#AED6F1','IIIb':'#3498DB','IIIc':'#1F618D','IIIlike':'#5D6D7E','IV':'#F4D03F','IVlike':'#F8C471','unknown':'#17202A'}
lines = labeled_leaves['Target'].apply(lambda x: x.split(' ')[0]).values +[',label,node,'+color_map[x]+',1,normal\n' for x in labeled_leaves['type'].values]
lines = set(lines)

# %%
uclust_data[uclust_data['type'] == 'II']
#labeled_leaves
# Out:
#       Type  Cluster  Size    %Id Strand Qlo Tlo      Alignment  \
# 30       H        4   459   80.6      .   0   0           459M
# 6974     H        4   451   78.0      .   0   0       6I451M2I
# 6975     H        2   451   76.0      .   0   0  9I73M3I378M2I
# 6976     H        4   451   90.2      .   0   0       6I451M2I
# 13947    H      175   452   71.0      .   0   0  6I30M7I422M3I
# 13948    H        4   451  100.0      .   0   0       6I451M2I
# 13949    H        4   451   89.4      .   0   0       6I451M2I
# 21071    H        7   462   85.1      .   0   0  6I25MD436M18I
# 21072    H        4   451   84.3      .   0   0       6I451M2I
# 28190    H       18   462   87.0      .   0   0  6I76M4D382M2I
# 28191    H      350   451  100.0      .   0   0       6I451M2I
# 35342    H        2   454   79.5      .   0   0       9I454M2I
# 49406    H        2   451   75.6      .   0   0  9I66M3I385M2I
# 49407    H       18   455   90.8      .   0   0  6I438M3I17M2I
# 56620    H        7   461   99.8      .   0   0      6I461M18I
# 56621    H        4   451   89.4      .   0   0       6I451M2I
#
#                                                    Query  \
# 30       ABB41020_Thiomicrospira_crunogena_XCL_2_II__REF
# 6974       AAC38280_Riftia_pachyptila_endosymbiont_I_REF
# 6975       P50922_Rhodobacter_capsulatus_ATCC11166_I_REF
# 6976              Thiobacillus_denitrificans_AAA9917_REF
# 13947          AAN52766_Rhodopseudomonas_palustris_I_REF
# 13948      Halothiobacillus_neapolitanus_YP_00326297_REF
# 13949  YP002220242_Acidithiobacillus_ferrooxidans_ATC...
# 21071                     AAG37859_Symbiodinium_sp_I_REF
# 21072      YP_522655_Rhodoferax_ferrireducens_T118_I_REF
# 28190          Mariprofundus_ferrooxydans_ZP_0145121_REF
# 28191  YP_422059_Magnetospirillum_magnetotacticum_AMB...
# 35342          Desulfovibrio_aespoeensis_YP_00412229_REF
# 49406         231173_pdb_5RUB_A_Rhodospirillum_Rubru_REF
# 49407               Q59462_Hydrogenovibrio_marinus_I_REF
# 56620                  AAA98748_Gonyaulax_polyedra_I_REF
# 56621     YP003522651_Sideroxydans_lithotrophicus_ES_REF
#
#                                                   Target  \
# 30                                 RBC3_1 WP_012823967.1
# 6974                               RBC3_1 WP_012823967.1
# 6975         RBCSeed_25 gi|771607269|ref|WP_045218222.1|
# 6976                               RBC3_1 WP_012823967.1
# 13947                 RBC_22 gi|269148484|gb|ACZ28625.1|
# 13948                              RBC3_1 WP_012823967.1
# 13949                              RBC3_1 WP_012823967.1
# 21071          RBC_16 gi|84029424|sp|Q42813.2|RBL2_LINPO
# 21072                              RBC3_1 WP_012823967.1
# 28190  gi|657350008|ref|WP_029406688.1| ribulose 1,5-...
# 28191           RBC2_41 gi|499704342|ref|WP_011385076.1|
# 35342        RBCSeed_25 gi|771607269|ref|WP_045218222.1|
# 49406        RBCSeed_25 gi|771607269|ref|WP_045218222.1|
# 49407  gi|657350008|ref|WP_029406688.1| ribulose 1,5-...
# 56620          RBC_16 gi|84029424|sp|Q42813.2|RBL2_LINPO
# 56621                              RBC3_1 WP_012823967.1
#
#                                                       ID   Organism type
# 30       ABB41020_Thiomicrospira_crunogena_XCL_2_II__REF  reference   II
# 6974       AAC38280_Riftia_pachyptila_endosymbiont_I_REF  reference   II
# 6975       P50922_Rhodobacter_capsulatus_ATCC11166_I_REF  reference   II
# 6976              Thiobacillus_denitrificans_AAA9917_REF  reference   II
# 13947          AAN52766_Rhodopseudomonas_palustris_I_REF  reference   II
# 13948      Halothiobacillus_neapolitanus_YP_00326297_REF  reference   II
# 13949  YP002220242_Acidithiobacillus_ferrooxidans_ATC...  reference   II
# 21071                     AAG37859_Symbiodinium_sp_I_REF  reference   II
# 21072      YP_522655_Rhodoferax_ferrireducens_T118_I_REF  reference   II
# 28190          Mariprofundus_ferrooxydans_ZP_0145121_REF  reference   II
# 28191  YP_422059_Magnetospirillum_magnetotacticum_AMB...  reference   II
# 35342          Desulfovibrio_aespoeensis_YP_00412229_REF  reference   II
# 49406         231173_pdb_5RUB_A_Rhodospirillum_Rubru_REF  reference   II
# 49407               Q59462_Hydrogenovibrio_marinus_I_REF  reference   II
# 56620                  AAA98748_Gonyaulax_polyedra_I_REF  reference   II
# 56621     YP003522651_Sideroxydans_lithotrophicus_ES_REF  reference   II

# %%
with open('../data/itol_legend_template.txt','r') as file:
    with open("../output/type_legend.txt", "w") as f1:
        for row in file:
            f1.write(row)
        for line in lines:
            f1.write(line)
        file.close()
        f1.close()

# %%
flamholz_data = pd.DataFrame([x.description for x in SeqIO.parse('../data/flamholz_et_al_2019_kinetically_characterized.faa', "fasta")],columns=['kinetic_ID'])
uclust_data = uclust_data.merge(flamholz_data, left_on='Query', right_on='kinetic_ID',how='left')
kinetic_measured = uclust_data[~pd.isna(uclust_data['kinetic_ID'])]
lines = kinetic_measured['Target'].apply(lambda x: x.split(' ')[0]).values + ',1,-1\n'

synth_data = pd.DataFrame([x.description for x in SeqIO.parse('../data/milo_synthetized_rubisco.faa', "fasta")],columns=['syn_ID'])
uclust_data = uclust_data.merge(synth_data, left_on='Query', right_on='syn_ID',how='left')
synth = uclust_data[~pd.isna(uclust_data['syn_ID'])]
lines_synth = synth['Target'].apply(lambda x: x.split(' ')[0]).values + ',-1,1\n'

with open('../data/kinetic_sampling_legend.txt','r') as file:
    with open("../output/kinetic_legend.txt", "w") as f1:
        for row in file:
            f1.write(row)
        for line in lines:
            f1.write(line)
        for line in lines_synth:
            f1.write(line)
        file.close()
        f1.close()

# %%
uclust_data[~pd.isna(uclust_data['kinetic_ID'])]
#uclust_data.loc[uclust_data['Query'].str.contains('AAA26115.1'),'Query'].loc[47373]
#flamholz_data.loc[0,'kinetic_ID']
# Out:
#       Type  Cluster  Size   %Id Strand Qlo Tlo                 Alignment  \
# 158      H       26   477  84.2      .   0   0                   I475M2D
# 290      H       26   476  82.8      .   0   0                  I468MD7M
# 551      H       26   482  83.4      .   0   0                    6D476M
# 940      H       26   477  82.9      .   0   0                   I475M2D
# 1306     H       26   472  75.6      .   0   0                  9I467M5D
# 1694     H       26   485  84.8      .   0   0                  I475M10D
# 1993     H       26   475  84.2      .   0   0                     I475M
# 3349     H       26   480  84.4      .   0   0                   I475M5D
# 6928     H       99   475  75.6      .   0   0     134M60D35M12D234M287I
# 7139     H       26   477  83.6      .   0   0                   I475M2D
# 7238     H       26   477  83.2      .   0   0                   I475M2D
# 7239     H       26   477  83.2      .   0   0                   I475M2D
# 7265     H       99   468  74.8      .   0   0     134M60D35M12D227M294I
# 7297     H       26   477  83.4      .   0   0                   I475M2D
# 7608     H      112   488  76.1      .   0   0            12D238M91D147M
# 7741     H       99   484  74.2      .   0   0   7D134M60D35M12D236M285I
# 8195     H       26   485  84.6      .   0   0                  I475M10D
# 8438     H       26   475  85.3      .   0   0                     I475M
# 10089    H       99   475  76.8      .   0   0     134M60D35M12D234M287I
# 10230    H       99   475  73.1      .   0   0     134M60D35M12D234M287I
# 10713    H       34   488  83.5      .   0   0                29D425M34D
# 11146    H       99   481  74.8      .   0   0     134M60D35M12D240M281I
# 13849    H       99   484  74.4      .   0   0     134M60D35M12D243M278I
# 13850    H       99   480    74      .   0   0     134M60D35M12D239M282I
# 14023    H       26   476  87.8      .   0   0                      476M
# 14137    H       26   477  83.6      .   0   0                   I475M2D
# 14238    H       99   480  73.5      .   0   0     134M60D35M12D239M282I
# 14276    H       99   476  74.4      .   0   0  134M60D35M12D227MD7M287I
# 14277    H       99   476  74.4      .   0   0  134M60D35M12D227MD7M287I
# 14513    H       26   477  84.2      .   0   0                   I475M2D
# ...    ...      ...   ...   ...    ...  ..  ..                       ...
# 42975    H       26   477  84.2      .   0   0                   I475M2D
# 42976    H       26   477  84.2      .   0   0                   I475M2D
# 42977    H       26   477  84.2      .   0   0                   I475M2D
# 42978    H       26   477  84.2      .   0   0                   I475M2D
# 42979    H       26   477  84.2      .   0   0                   I475M2D
# 42980    H       26   477  84.2      .   0   0                   I475M2D
# 44691    H       99   485  74.6      .   0   0     134M60D35M12D244M277I
# 44713    H       99   477  74.4      .   0   0     134M60D35M12D236M285I
# 46097    H       99   475  75.8      .   0   0     134M60D35M12D234M287I
# 46343    H       99   475  75.8      .   0   0     134M60D35M12D234M287I
# 47050    H       99   475  76.4      .   0   0     134M60D35M12D234M287I
# 47373    H      244   486  81.6      .   0   0                  71D414MD
# 48056    H       26   470  74.9      .   0   0                  9I467M3D
# 48988    H       26   876  83.2      .   0   0                 I475M401D
# 49323    H       26   476  83.4      .   0   0                    I475MD
# 49412    H       99   477  75.3      .   0   0     134M60D35M12D236M285I
# 49453    H       26   477  83.8      .   0   0                   I475M2D
# 49492    H       26   475  84.2      .   0   0                     I475M
# 49573    H       26   479  83.8      .   0   0                   I475M4D
# 49644    H       99   480  73.5      .   0   0     134M60D35M12D239M282I
# 49645    H       99   480  73.5      .   0   0     134M60D35M12D239M282I
# 49646    H       99   480  73.5      .   0   0     134M60D35M12D239M282I
# 49931    H       99   477  74.2      .   0   0     134M60D35M12D236M285I
# 49987    H       26   477    84      .   0   0                   I475M2D
# 50350    H       26   475  82.1      .   0   0                     I475M
# 52988    H       99   482  74.9      .   0   0   7D134M60D35M12D234M287I
# 54512    H       99   475  75.2      .   0   0     134M60D35M12D234M287I
# 54518    H       26   471  85.4      .   0   0                 4I5MI466M
# 56411    C      225     1     *      *   *   *                         *
# 56620    C      434     2     *      *   *   *                         *
#
#                                                    Query  \
# 158    AFV62913.1 ribulose-1,5-bisphosphate carboxyla...
# 290    NP_043033.1 ribulose-1,5-bisphosphate carboxyl...
# 551    ARJ58803.1 ribulose-1,5-bisphosphate carboxyla...
# 940    YP_009267237.1 ribulose-1,5-bisphosphate carbo...
# 1306   AAA23328.1 ribulose-1,5-bisphosphate carboxyla...
# 1694   ADW80658.1 ribulose-1,5-bisphosphate carboxyla...
# 1993   ADK47564.1 ribulose-1,5-bisphosphate carboxyla...
# 3349   AAK14845.1 ribulose-1,5-bisphosphate carboxyla...
# 6928   SCM15150.1 Large subunit of Ribulose-1,5-bisph...
# 7139   ABK79588.1 ribulose-1,5-bisphosphate carboxyla...
# 7238   NP_114267.1 ribulose-1,5-bisphosphate carboxyl...
# 7239   YP_009054844.1 ribulose-1,5-bisphosphate carbo...
# 7265   YP_008815759.1 ribulose 1,5-bisphosphate carbo...
# 7297   AAA32046.1 ribulose 1,5-bisphosphate carboxyla...
# 7608   ABU53651.1 ribulose-1,5-bisphosphate carboxyla...
# 7741   AGJ76630.1 ribulose-1,5-bisphosphate carboxyla...
# 8195   AIL52300.1 ribulose-1,5-bisphosphate carboxyla...
# 8438   NP_958405.1 ribulose-1,5-bisphosphate carboxyl...
# 10089  AOG66212.1 ribulose-1,5-bisphosphate carboxyla...
# 10230  AXJ93223.1 ribulose-1,5-bisphosphate carboxyla...
# 10713  sp|P14959.2|RBL_OLILU RecName: Full=Ribulose b...
# 11146  ABJ89687.1 ribulose-1,5-bisphosphate carboxyla...
# 13849  ATL76552.1 ribulose-1,5-bisphosphate carboxyla...
# 13850  SCM15159.1 Large subunit of Ribulose-1,5-bisph...
# 14023  KHG42839.1 ribulose 1,5-bisphosphate carboxyla...
# 14137  AAX44989.1 ribulose-1,5-bisphosphate carboxyla...
# 14238  SCM15158.1 Large subunit of Ribulose-1,5-bisph...
# 14276  ABK79504.1 ribulose-1,5-bisphosphate carboxyla...
# 14277  ASV52260.1 ribulose-1,5-bisphosphate carboxyla...
# 14513  AOG74970.1 ribulose-1,5-bisphosphate carboxyla...
# ...                                                  ...
# 42975  AGY93378.1 ribulose-1,5-bisphosphate carboxyla...
# 42976  AGY93291.1 ribulose-1,5-bisphosphate carboxyla...
# 42977  AGY93639.1 ribulose-1,5-bisphosphate carboxyla...
# 42978  AGY93552.1 ribulose-1,5-bisphosphate carboxyla...
# 42979  YP_052757.1 ribulose-1,5-bisphosphate carboxyl...
# 42980  BAA00147.1 ribulose-1,5-bisphosphate carboxyla...
# 44691  YP_588125.1 ribulose-1,5-bisphosphate carboxyl...
# 44713  NP_054507.1 ribulose-1,5-bisphosphate carboxyl...
# 46097  AAY68360.1 ribulose-1,5-bisphosphate carboxyla...
# 46343  CAB88737.1 ribulose-1,5-bisphosphate carboxyla...
# 47050  YP_538747.1 ribulose-1,5-bisphosphate carboxyl...
# 47373  AAA26115.1 ribulose-1,5-bisphosphate carboxyla...
# 48056  sp|Q7V6F8.1|RBL_PROMM RecName: Full=Ribulose b...
# 48988  AGP51153.1 ribulose-1,5-bisphosphate carboxyla...
# 49323  YP_009233700.1 ribulose-1,5-bisphosphate carbo...
# 49412  YP_009156633.1 ribulose-1,5-bisphosphate carbo...
# 49453  YP_009156214.1 ribulose-1,5-bisphosphate carbo...
# 49492  YP_635974.1 ribulose-1,5-bisphosphate carboxyl...
# 49573  AGY93465.1 ribulose-1,5-bisphosphate carboxyla...
# 49644  YP_009260243.1 ribulose-1,5-bisphosphate carbo...
# 49645  SCM15151.1 Large subunit of Ribulose-1,5-bisph...
# 49646  SCM15160.1 Large subunit of Ribulose-1,5-bisph...
# 49931  ADV41949.1 ribulose-1,5-bisphosphate carboxyla...
# 49987  AOX22505.1 ribulose-1,5-bisphosphate carboxyla...
# 50350  NP_041936.1 ribulose-1,5-bisphosphate carboxyl...
# 52988  CAH10354.1 ribulose 1,5 bisphosphate carboxyla...
# 54512  YP_008145856.1 ribulose-1,5-bisphosphate carbo...
# 54518  ACA99786.1 ribulose-1,5-bisphosphate carboxyla...
# 56411  ATS18068.1 carbon dioxide concentrating mechan...
# 56620  ACH82850.1 ribulose-1,5-bisphosphate carboxyla...
#
#                                                   Target   ID type comments  \
# 158    gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 290    gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 551    gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 940    gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 1306   gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 1694   gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 1993   gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 3349   gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 6928   gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 7139   gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 7238   gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 7239   gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 7265   gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 7297   gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 7608   gi|15281545|gb|AAK94305.1| ribulose-1,5-bispho...  NaN  NaN      NaN
# 7741   gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 8195   gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 8438   gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 10089  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 10230  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 10713  gi|703265142|emb|CDI73524.1| ribulose-1,5-bisp...  NaN  NaN      NaN
# 11146  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 13849  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 13850  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 14023  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 14137  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 14238  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 14276  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 14277  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 14513  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# ...                                                  ...  ...  ...      ...
# 42975  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 42976  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 42977  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 42978  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 42979  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 42980  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 44691  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 44713  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 46097  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 46343  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 47050  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 47373  gi|388537986|gb|AFK63174.1| ribulose bisophosp...  NaN  NaN      NaN
# 48056  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 48988  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 49323  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 49412  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 49453  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 49492  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 49573  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 49644  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 49645  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 49646  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 49931  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 49987  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 50350  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 52988  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 54512  gi|223541024|gb|EEF42581.1| conserved hypothet...  NaN  NaN      NaN
# 54518  gi|518331021|ref|WP_019501228.1| ribulose-bisp...  NaN  NaN      NaN
# 56411  ATS18068.1 carbon dioxide concentrating mechan...  NaN  NaN      NaN
# 56620  ACH82850.1 ribulose-1,5-bisphosphate carboxyla...  NaN  NaN      NaN
#
#                                               kinetic_ID
# 158    AFV62913.1 ribulose-1,5-bisphosphate carboxyla...
# 290    NP_043033.1 ribulose-1,5-bisphosphate carboxyl...
# 551    ARJ58803.1 ribulose-1,5-bisphosphate carboxyla...
# 940    YP_009267237.1 ribulose-1,5-bisphosphate carbo...
# 1306   AAA23328.1 ribulose-1,5-bisphosphate carboxyla...
# 1694   ADW80658.1 ribulose-1,5-bisphosphate carboxyla...
# 1993   ADK47564.1 ribulose-1,5-bisphosphate carboxyla...
# 3349   AAK14845.1 ribulose-1,5-bisphosphate carboxyla...
# 6928   SCM15150.1 Large subunit of Ribulose-1,5-bisph...
# 7139   ABK79588.1 ribulose-1,5-bisphosphate carboxyla...
# 7238   NP_114267.1 ribulose-1,5-bisphosphate carboxyl...
# 7239   YP_009054844.1 ribulose-1,5-bisphosphate carbo...
# 7265   YP_008815759.1 ribulose 1,5-bisphosphate carbo...
# 7297   AAA32046.1 ribulose 1,5-bisphosphate carboxyla...
# 7608   ABU53651.1 ribulose-1,5-bisphosphate carboxyla...
# 7741   AGJ76630.1 ribulose-1,5-bisphosphate carboxyla...
# 8195   AIL52300.1 ribulose-1,5-bisphosphate carboxyla...
# 8438   NP_958405.1 ribulose-1,5-bisphosphate carboxyl...
# 10089  AOG66212.1 ribulose-1,5-bisphosphate carboxyla...
# 10230  AXJ93223.1 ribulose-1,5-bisphosphate carboxyla...
# 10713  sp|P14959.2|RBL_OLILU RecName: Full=Ribulose b...
# 11146  ABJ89687.1 ribulose-1,5-bisphosphate carboxyla...
# 13849  ATL76552.1 ribulose-1,5-bisphosphate carboxyla...
# 13850  SCM15159.1 Large subunit of Ribulose-1,5-bisph...
# 14023  KHG42839.1 ribulose 1,5-bisphosphate carboxyla...
# 14137  AAX44989.1 ribulose-1,5-bisphosphate carboxyla...
# 14238  SCM15158.1 Large subunit of Ribulose-1,5-bisph...
# 14276  ABK79504.1 ribulose-1,5-bisphosphate carboxyla...
# 14277  ASV52260.1 ribulose-1,5-bisphosphate carboxyla...
# 14513  AOG74970.1 ribulose-1,5-bisphosphate carboxyla...
# ...                                                  ...
# 42975  AGY93378.1 ribulose-1,5-bisphosphate carboxyla...
# 42976  AGY93291.1 ribulose-1,5-bisphosphate carboxyla...
# 42977  AGY93639.1 ribulose-1,5-bisphosphate carboxyla...
# 42978  AGY93552.1 ribulose-1,5-bisphosphate carboxyla...
# 42979  YP_052757.1 ribulose-1,5-bisphosphate carboxyl...
# 42980  BAA00147.1 ribulose-1,5-bisphosphate carboxyla...
# 44691  YP_588125.1 ribulose-1,5-bisphosphate carboxyl...
# 44713  NP_054507.1 ribulose-1,5-bisphosphate carboxyl...
# 46097  AAY68360.1 ribulose-1,5-bisphosphate carboxyla...
# 46343  CAB88737.1 ribulose-1,5-bisphosphate carboxyla...
# 47050  YP_538747.1 ribulose-1,5-bisphosphate carboxyl...
# 47373  AAA26115.1 ribulose-1,5-bisphosphate carboxyla...
# 48056  sp|Q7V6F8.1|RBL_PROMM RecName: Full=Ribulose b...
# 48988  AGP51153.1 ribulose-1,5-bisphosphate carboxyla...
# 49323  YP_009233700.1 ribulose-1,5-bisphosphate carbo...
# 49412  YP_009156633.1 ribulose-1,5-bisphosphate carbo...
# 49453  YP_009156214.1 ribulose-1,5-bisphosphate carbo...
# 49492  YP_635974.1 ribulose-1,5-bisphosphate carboxyl...
# 49573  AGY93465.1 ribulose-1,5-bisphosphate carboxyla...
# 49644  YP_009260243.1 ribulose-1,5-bisphosphate carbo...
# 49645  SCM15151.1 Large subunit of Ribulose-1,5-bisph...
# 49646  SCM15160.1 Large subunit of Ribulose-1,5-bisph...
# 49931  ADV41949.1 ribulose-1,5-bisphosphate carboxyla...
# 49987  AOX22505.1 ribulose-1,5-bisphosphate carboxyla...
# 50350  NP_041936.1 ribulose-1,5-bisphosphate carboxyl...
# 52988  CAH10354.1 ribulose 1,5 bisphosphate carboxyla...
# 54512  YP_008145856.1 ribulose-1,5-bisphosphate carbo...
# 54518  ACA99786.1 ribulose-1,5-bisphosphate carboxyla...
# 56411  ATS18068.1 carbon dioxide concentrating mechan...
# 56620  ACH82850.1 ribulose-1,5-bisphosphate carboxyla...
#
# [120 rows x 14 columns]

# %%
f = open('../output/type1_fasttree.txt','r')
type1_id = [x.rstrip('\n').replace(' ','_') for x in f.readlines()]
aln = AlignIO.read('../output/03_uclust_all_0.7_trimmed.aln',format='fasta')
type1 = []
for record in aln:
    if record.id in type1_id:
        type1.append(record)
        
with open(r"../output/05_type1_fasttree.aln", "w") as output_handle:
    SeqIO.write(type1, output_handle, "fasta")

# %%
f = open('../output/type2_fasttree.txt','r')
type2_id = [x.rstrip('\n').replace(' ','_') for x in f.readlines()]
aln = AlignIO.read('../output/03_uclust_all_0.7_trimmed.aln',format='fasta')
type2 = []
for record in aln:
    if record.id in type2_id:
        type2.append(record)
        
with open(r"../output/05_type2_fasttree.aln", "w") as output_handle:
    SeqIO.write(type2, output_handle, "fasta")

# %%
f = open('../output/type2_3_fastree.txt','r')
type2_3_id = [x.rstrip('\n').replace(' ','_') for x in f.readlines()]
aln = AlignIO.read('../output/03_uclust_all_0.7_trimmed.aln',format='fasta')
type2_3 = []
for record in aln:
    if record.id in type2_3_id:
        type2_3.append(record)
        
with open(r"../output/05_type2_3_fasttree.aln", "w") as output_handle:
    SeqIO.write(type2_3, output_handle, "fasta")

# %%
f2 = open('../output/type2_fasttree.txt','r')
type2_id = [x.rstrip('\n').replace(' ','_') for x in f2.readlines()]

f1 = open('../output/type1_fasttree.txt','r')
type1_id = [x.rstrip('\n').replace(' ','_') for x in f1.readlines()]

f = open('../output/type2_3_fastree.txt','r')
type2_3_id = [x.rstrip('\n').replace(' ','_') for x in f.readlines()]

f4 = open('../output/type4_fasttree.txt','r')
type4_id = [x.rstrip('\n').replace(' ','_') for x in f4.readlines()]

aln = AlignIO.read('../output/03_uclust_all_0.7_trimmed.aln',format='fasta')
type3 = []
not_type4 = []
for record in aln:
    if record.id not in type4_id:
        not_type4.append(record)
    if record.id not in type1_id+type2_id+type2_3_id+type4_id:
        type3.append(record)
#with open(r"../output/05_type2_3_fasttree.aln", "w") as output_handle:
#    SeqIO.write(type2_3, output_handle, "fasta")

# %%
len(type1)
# Out:
# 28

# %%
from Shannon import shannon_entropy_list_msa,shannon_entropy
aln1 = AlignIO.read('../output/05_type1_fasttree.aln',format='fasta')
sum(shannon_entropy_list_msa(aln1))
# Out:
# 781.5564408080079
