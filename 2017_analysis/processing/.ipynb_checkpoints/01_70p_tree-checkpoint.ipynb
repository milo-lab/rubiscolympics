# %%
import pandas as pd
from Bio import SeqIO, AlignIO, Seq
import numpy as np
from collections import Counter
from helper import *
import python_cipres.client as CipresClient

# %% [markdown]
# ### Cluster sequences using uclust

# %%
! mkdir -p ../output/01_70p_tree
# !../bin/usearch11.0.667_i86linux32 -cluster_fast ../output/00_100p_tree/uclust_all_1.faa -id 0.7 -uc ../output/01_70p_tree/uclust_all_0.7.uc
# Out:
# usearch v11.0.667_i86linux32, 4.0Gb RAM (16.3Gb total), 8 cores
# (C) Copyright 2013-18 Robert C. Edgar, all rights reserved.
# https://drive5.com/usearch
#
# License: yinonmoise.baron@weizmann.ac.il
#
# 00:00 67Mb    100.0% Reading ../output/00_100p_tree/uclust_all_1.faa
# 00:00 105Mb   100.0% DF
# 00:00 105Mb  40945 seqs, 40945 uniques, 40945 singletons (100.0%)
# 00:00 105Mb  Min size 1, median 1, max 1, avg 1.00
# 00:00 111Mb   100.0% DB
# 00:03 176Mb   100.0% 884 clusters, max size 17546, avg 46.3
#
#       Seqs  40945 (40.9k)
#   Clusters  884
#   Max size  17546 (17.5k)
#   Avg size  46.3
#   Min size  1
# Singletons  452, 1.1% of seqs, 51.1% of clusters
#    Max mem  176Mb
#       Time  3.00s
# Throughput  13.6k seqs/sec.

# %% [markdown]
# ### Take only cluster fasta files and create csv file

# %%
parse_uclust(infile='../output/01_70p_tree/uclust_all_0.7.uc',
             fasta='../output/00_100p_tree/uclust_all_1.faa',
             outfasta='../output/01_70p_tree/uclust_all_0.7.faa',
             outfile='../output/01_70p_tree/uclust_all_0.7.csv'
            )

# %% [markdown]
# ## Create multiple sequence alignment

# %%
# !../bin/mafft-linux64/mafft.bat ../output/01_70p_tree/uclust_all_0.7.faa > ../output/01_70p_tree/uclust_all_0.7.aln
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# rescale = 1
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#   801 / 884
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#   880 / 884
# done.
#
# Progressive alignment 1/2...
# STEP    19 / 883
# Reallocating..done. *alloclen = 2637
# STEP   801 / 883
# Reallocating..done. *alloclen = 4617
#
# done.
#
# Making a distance matrix from msa..
#   800 / 884
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#   880 / 884
# done.
#
# Progressive alignment 2/2...
# STEP   168 / 883
# Reallocating..done. *alloclen = 2492
# STEP   801 / 883
# Reallocating..done. *alloclen = 3633
#
# Reallocating..done. *alloclen = 4732
#
# done.
#
# disttbfast (aa) Version 7.427
# alg=A, model=BLOSUM62, 1.53, -0.00, -0.00, noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# If unsure which option to use, try 'mafft --auto input > output'.
# For more information, see 'mafft --help', 'mafft --man' and the mafft page.
#
# The default gap scoring scheme has been changed in version 7.110 (2013 Oct).
# It tends to insert more gaps into gap-rich regions than previous versions.
# To disable this change, add the --leavegappyregion option.

# %% [markdown]
# ## Clean MSA to contain only positions with more than 5% coverage (based on Jaffe et al. 2018)

# %%
clean_aln(infile='../output/01_70p_tree/uclust_all_0.7.aln',
          outfile='../output/01_70p_tree/uclust_all_0.7_trimmed.aln')

# %% [markdown]
# ### Run RaxML on CIPRES

# %%
cip = CipresClient.Client(appname='RO',
                    appID='rubisco_phylogeny-49F87B124F3D429FBE12F95E4254DDEA',
                    baseUrl='https://cipresrest.sdsc.edu/cipresrest/v1',
                    username='yinonbaron',
                    password='Mchcav11~')

# %%
job = cip.submitJob(vParams={'toolId': 'RAXMLHPC8_REST_XSEDE',
                       'datatype_': 'protein',
                       'runtime_': '160',
                       'select_analysis_': 'fa',
                       'choose_bootstrap_': 'x',
                       'printbrlength_': '1'},
              inputParams={'infile_': '../output/01_70p_tree/uclust_all_0.7_trimmed.aln'},
              metadata={'statusEmail':'true'})

# %%
if cip.getJobStatus(jobHandle=job.jobHandle).isDone():
    # !mkdir -p ../output/01_70p_tree/RaxML/
    job.downloadResults('../output/01_70p_tree//RaxML/')
else:
    print('Job ' + job.jobHandle + ' not finished')

# %%
#!curl -u yinonbaron:Mchcav11~ -H cipres-appkey:rubisco_phylogeny-49F87B124F3D429FBE12F95E4254DDEA https://cipresrest.sdsc.edu/cipresrest/v1/job/yinonbaron -F tool=RAXMLHPC8_REST_XSEDE  -F input.infile_=@../output/01_70p_tree/uclust_all_0.7_trimmed.aln -F metadata.statusEmail=true -F vparam.datatype_=protein -F vparam.runtime_=160 -F  vparam.select_analysis_=fa -F vparam.choose_bootstrap_=x -F vparam.printbrlength_=1

# %%
# Optional - create tree using fasttree
#!../bin/FastTree -spr 4 -mlacc 2 -slownni ../output/03_uclust_all_0.7_trimmed.aln > ../output/04_uclust_all_0.7.nwk

# %%
add_type(type_file='../output/00_100p_tree/uclust_all_1_rubisco_types.csv',
         seq_file='../output/01_70p_tree/uclust_all_0.7.csv',
         outfile='../output/01_70p_tree/type_legend.txt')

# %%
uc = pd.read_csv('../output/01_70p_tree/uclust_all_0.7.csv')
kin = pd.read_csv('../output/00_100p_tree/uclust_all_1_kinetic_data.csv')
m = uc.merge(kin,left_on = 'Query', right_on = 'kinetic_ID')
m['ID'] = m.Target.apply(lambda x: x.split(' ')[0])
m.groupby('ID')['kinetic_ID'].count()
# Out:
# ID
# RBCSeed_14                             1
# RBCSeed_25                             1
# Tk                                     1
# gi|1011359504|ref|WP_062272591.1|      1
# gi|1271067907|gb|PHT72509.1|           2
# gi|15281545|gb|AAK94305.1|             2
# gi|29726049|gb|AAL46534.1|             2
# gi|358252603|gb|AEU04903.1|            8
# gi|388537986|gb|AFK63174.1|            1
# gi|499181544|ref|WP_010879084.1|       1
# gi|503184930|ref|WP_013419591.1|       1
# gi|518331021|ref|WP_019501228.1|     160
# gi|523387592|emb|CDF56957.1|           2
# gi|703265142|emb|CDI73524.1|          12
# Name: kinetic_ID, dtype: int64

# %%
type_file='../output/00_100p_tree/uclust_all_1_rubisco_types.csv'
seq_file='../output/01_70p_tree/uclust_all_0.7.csv'
outfile='../output/01_70p_tree/type_legend.txt'

labels = pd.read_csv(type_file)
uclust_data = pd.read_csv(seq_file)
uclust_data = uclust_data[uclust_data['Type'] !='S']
uclust_data.loc[uclust_data['Target'] == '*','Target'] = uclust_data.loc[uclust_data['Target'] == '*','Query']
uclust_data = uclust_data.merge(labels, left_on='Query', right_on='ID',how='left')
labeled_leaves = uclust_data[~pd.isna(uclust_data['type'])]
color_map = {'I': '#28B463',
             'II': '#E74C3C',
             'II/III':'#AF7AC5',
             'IIIa':'#AED6F1',
             'IIIb':'#3498DB',
             'IIIc':'#1F618D',
             'IIIlike':'#5D6D7E',
             'IV':'#F4D03F',
             'IVlike':'#F8C471',
             'unknown':'#F442D4'}
lines = labeled_leaves['Target'].apply(lambda x: x.split(' ')[0]).values +[',label,node,'+color_map[x]+',1,normal\n' for x in labeled_leaves['type'].values]
lines = set(lines)
'''
with open('../data/itol_legend_template.txt','r') as file:
    with open(outfile, "w") as f1:
        for row in file:
            f1.write(row)
        for line in lines:
            f1.write(line)
        file.close()
        f1.close()
        '''
# Out:
# '\nwith open(\'../data/itol_legend_template.txt\',\'r\') as file:\n    with open(outfile, "w") as f1:\n        for row in file:\n            f1.write(row)\n        for line in lines:\n            f1.write(line)\n        file.close()\n        f1.close()\n        '

# %%
labeled_leaves
# Out:
#       Type  Cluster  Size   %Id Strand Qlo Tlo        Alignment  \
# 6        H        0   461  77.6      .   0   0           2D459M
# 41       H       20   419  72.2      .   0   0     2D50MI367M3I
# 42       H       34   373  89.8      .   0   0          50I373M
# 54       H       51   414  99.0      .   0   0             414M
# 56       H       34   336  92.6      .   0   0          87I336M
# 60       H       44   430  77.2      .   0   0             430M
# 62       H       21   422  71.9      .   0   0        28MI394MI
# 72       H       50   438  89.8      .   0   0       337M4I101M
# 86       H       51   414  90.3      .   0   0             414M
# 229      H        2   356  72.3      .   0   0       71D285M50I
# 272      H       55   483  79.8      .   0   0       24D425M34D
# 357      H       55   476  71.5      .   0   0       18D425M33D
# 623      H       55   493  80.7      .   0   0       34D425M34D
# 644      H       55   493  73.2      .   0   0       34D425M34D
# 874      H       56   430  79.7      .   0   0         2D423M5D
# 1164     H       43   475  85.1      .   0   0            I475M
# 1314     H       65   423  74.2      .   0   0  D339MI80M3I3M6I
# 1646     H       55   488  74.1      .   0   0       30D425M33D
# 1779     H       65   433  76.6      .   0   0            D432M
# 1836     H       57   431  71.2      .   0   0            D430M
# 2135     H       55   470  81.2      .   0   0       11D425M34D
# 2345     H       64   390  98.2      .   0   0          75I390M
# 2560     H       66   486  74.1      .   0   0         9D474M3D
# 3108     H       43   473  77.4      .   0   0         8I468M5D
# 3310     H       34   351  90.6      .   0   0       38I351M34I
# 3490     H       64   445  92.4      .   0   0       435MD9M21I
# 3655     H       65   429  72.7      .   0   0   D77M3I259MI92M
# 3755     H       64   423  96.5      .   0   0          423M42I
# 4024     H       43   475  82.9      .   0   0            I475M
# 4761     H       43   474  70.8      .   0   0         7I469M5D
# ...    ...      ...   ...   ...    ...  ..  ..              ...
# 40265    C      591     2     *      *   *   *                *
# 40266    C      592     2     *      *   *   *                *
# 40267    C      593     1     *      *   *   *                *
# 40270    C      596     1     *      *   *   *                *
# 40272    C      598     4     *      *   *   *                *
# 40275    C      601     1     *      *   *   *                *
# 40305    C      631     1     *      *   *   *                *
# 40341    C      667     2     *      *   *   *                *
# 40345    C      671     1     *      *   *   *                *
# 40352    C      678     1     *      *   *   *                *
# 40354    C      680     4     *      *   *   *                *
# 40359    C      685     5     *      *   *   *                *
# 40368    C      694     2     *      *   *   *                *
# 40371    C      697     1     *      *   *   *                *
# 40397    C      723     2     *      *   *   *                *
# 40410    C      736     1     *      *   *   *                *
# 40412    C      738     1     *      *   *   *                *
# 40413    C      739     1     *      *   *   *                *
# 40418    C      744     1     *      *   *   *                *
# 40430    C      756     3     *      *   *   *                *
# 40454    C      780     1     *      *   *   *                *
# 40455    C      781     1     *      *   *   *                *
# 40456    C      782     1     *      *   *   *                *
# 40464    C      790     1     *      *   *   *                *
# 40467    C      793     1     *      *   *   *                *
# 40476    C      802     1     *      *   *   *                *
# 40482    C      808     1     *      *   *   *                *
# 40487    C      813     1     *      *   *   *                *
# 40488    C      814     1     *      *   *   *                *
# 40494    C      820     1     *      *   *   *                *
#
#                                                    Query  \
# 6      gi|2978568|gb|AAC38280.1| ribulose-1,5-bisphos...
# 41     gi|1572540067|emb|VDD89078.1| RuBisCO long cha...
# 42     gi|1572539574|emb|VDD88866.1| RuBisCO long cha...
# 54     gi|494803605|ref|WP_007539013.1| type III ribu...
# 56     gi|1572540253|emb|VDD89214.1| RuBisCO long cha...
# 60     gi|504680960|ref|WP_014868062.1| type III ribu...
# 62     gi|1572539949|emb|VDD88980.1| RuBisCO long cha...
# 72     gi|1572540177|emb|VDD89155.1| RuBisCO long cha...
# 86     gi|495596802|ref|WP_008321381.1| type III ribu...
# 229    gi|1572540261|emb|VDD89218.1| RuBisCO long cha...
# 272    gi|166078534|gb|ABY81245.1| ribulose-1,5-bisph...
# 357    gi|738479616|ref|WP_036429835.1| form I ribulo...
# 623    gi|30749269|pdb|1IWA|A Chain A, Rubisco From G...
# 644    gi|497544748|ref|WP_009858946.1| form I ribulo...
# 874    gi|37087672|sp|O58677.1|RBL_PYRHO RecName: Ful...
# 1164   gi|1384872478|gb|AWF83650.1| ribulose-1,5-bisp...
# 1314   gi|1572540025|emb|VDD89045.1| RuBisCO long cha...
# 1646   gi|158512861|sp|A2SFV1.1|RBL1A_METPP RecName: ...
# 1779   gi|1572541061|emb|VDS11157.1| RuBisCO long cha...
# 1836   gi|1572540039|emb|VDD89054.1| RuBisCO long cha...
# 2135   gi|1220464692|gb|ASO45429.1| ribulose-1,5-bisp...
# 2345   gi|1572539973|emb|VDD89004.1| RuBisCO long cha...
# 2560   gi|488805187|ref|WP_002717593.1| form I ribulo...
# 3108   gi|502433156|ref|WP_012784207.1| form I ribulo...
# 3310   gi|1572540293|emb|VDD89243.1| RuBisCO long cha...
# 3490   gi|1572540055|emb|VDD89065.1| RuBisCO long cha...
# 3655   gi|1572539518|emb|VDD88815.1| RuBisCO long cha...
# 3755   gi|1572539975|emb|VDD89005.1| RuBisCO long cha...
# 4024   gi|132051|sp|P00875.1|RBL_SPIOL RecName: Full=...
# 4761   gi|3183144|sp|Q51856.1|RBL_HYDTE RecName: Full...
# ...                                                  ...
# 40265  gi|1278357258|gb|PIY97215.1| ribulose-bisphosp...
# 40266  gi|1572539540|emb|VDD88835.1| RuBisCO long cha...
# 40267  gi|1572539494|emb|VDD88792.1| RuBisCO long cha...
# 40270  gi|1572540083|emb|VDD89090.1| RuBisCO long cha...
# 40272  gi|1572540003|emb|VDD89030.1| RuBisCO long cha...
# 40275  gi|1572540249|emb|VDD89207.1| RuBisCO long cha...
# 40305  gi|1572541021|emb|VDS11137.1| RuBisCO long cha...
# 40341  gi|1572540511|emb|VDD89260.1| RuBisCO long cha...
# 40345  gi|1572540513|emb|VDD89261.1| RuBisCO long cha...
# 40352  gi|1572539552|emb|VDD88845.1| RuBisCO long cha...
# 40354  gi|1572539654|emb|VDD88919.1| RuBisCO long cha...
# 40359  gi|1572539352|emb|VDD88682.1| RuBisCO long cha...
# 40368  gi|1572539620|emb|VDD88893.1| RuBisCO long cha...
# 40371  gi|1572540049|emb|VDD89062.1| RuBisCO long cha...
# 40397  gi|500137273|ref|WP_011813278.1| ribulose-bisp...
# 40410  gi|1572540139|emb|VDD89124.1| RuBisCO long cha...
# 40412  gi|1572540117|emb|VDD89110.1| RuBisCO long cha...
# 40413  gi|1572539414|emb|VDD88743.1| RuBisCO long cha...
# 40418  gi|1572540207|emb|VDD89172.1| RuBisCO long cha...
# 40430  gi|1572539486|emb|VDD88788.1| RuBisCO long cha...
# 40454  gi|1572540251|emb|VDD89211.1| RuBisCO long cha...
# 40455  gi|1572540197|emb|VDD89167.1| RuBisCO long cha...
# 40456  gi|1572539444|emb|VDD88763.1| RuBisCO long cha...
# 40464  gi|563911827|ref|WP_023807801.1| ribulose-bisp...
# 40467  gi|1572539492|emb|VDD88791.1| RuBisCO long cha...
# 40476  gi|1572539460|emb|VDD88771.1| RuBisCO long cha...
# 40482  gi|1277787165|gb|PIU03070.1| ribulose-bisphosp...
# 40487  gi|499775450|ref|WP_011456184.1| ribulose-bisp...
# 40488  gi|1572539632|emb|VDD88902.1| RuBisCO long cha...
# 40494  TARA_039.SAMEA2620106.270.0.1-0.22_378_10 /ann...
#
#                                                   Target  \
# 6      RBG_16_Gammaproteobacteria_62_13_RBG_16_scaffo...
# 41     gi|1572539700|emb|VDD88952.1| RuBisCO long cha...
# 42     gi|1572539402|emb|VDD88726.1| RuBisCO long cha...
# 54     gi|1124507462|ref|WP_074791909.1| type III rib...
# 56     gi|1572539402|emb|VDD88726.1| RuBisCO long cha...
# 60     gi|1519899714|gb|RPI40578.1| type III ribulose...
# 62     gi|1572539462|emb|VDD88772.1| RuBisCO long cha...
# 72     gi|735013727|gb|KHO47783.1| ribulose-bisphosph...
# 86     gi|1124507462|ref|WP_074791909.1| type III rib...
# 229    RBG_13_Archaea_46_16b_RBG_13_scaffold_4070_13 ...
# 272    gi|703265142|emb|CDI73524.1| ribulose-1,5-bisp...
# 357    gi|703265142|emb|CDI73524.1| ribulose-1,5-bisp...
# 623    gi|703265142|emb|CDI73524.1| ribulose-1,5-bisp...
# 644    gi|703265142|emb|CDI73524.1| ribulose-1,5-bisp...
# 874    gi|1491080228|gb|RLF78506.1| type III ribulose...
# 1164   gi|518331021|ref|WP_019501228.1| form I ribulo...
# 1314   gi|1276446210|gb|PIO08000.1| type III ribulose...
# 1646   gi|703265142|emb|CDI73524.1| ribulose-1,5-bisp...
# 1779   gi|1276446210|gb|PIO08000.1| type III ribulose...
# 1836   gi|1277768226|gb|PIT85720.1| type III ribulose...
# 2135   gi|703265142|emb|CDI73524.1| ribulose-1,5-bisp...
# 2345   gi|1572539530|emb|VDD88826.1| RuBisCO long cha...
# 2560   gi|1463752065|ref|WP_116707191.1| form I ribul...
# 3108   gi|518331021|ref|WP_019501228.1| form I ribulo...
# 3310   gi|1572539402|emb|VDD88726.1| RuBisCO long cha...
# 3490   gi|1572539530|emb|VDD88826.1| RuBisCO long cha...
# 3655   gi|1276446210|gb|PIO08000.1| type III ribulose...
# 3755   gi|1572539530|emb|VDD88826.1| RuBisCO long cha...
# 4024   gi|518331021|ref|WP_019501228.1| form I ribulo...
# 4761   gi|518331021|ref|WP_019501228.1| form I ribulo...
# ...                                                  ...
# 40265  gi|1278357258|gb|PIY97215.1| ribulose-bisphosp...
# 40266  gi|1572539540|emb|VDD88835.1| RuBisCO long cha...
# 40267  gi|1572539494|emb|VDD88792.1| RuBisCO long cha...
# 40270  gi|1572540083|emb|VDD89090.1| RuBisCO long cha...
# 40272  gi|1572540003|emb|VDD89030.1| RuBisCO long cha...
# 40275  gi|1572540249|emb|VDD89207.1| RuBisCO long cha...
# 40305  gi|1572541021|emb|VDS11137.1| RuBisCO long cha...
# 40341  gi|1572540511|emb|VDD89260.1| RuBisCO long cha...
# 40345  gi|1572540513|emb|VDD89261.1| RuBisCO long cha...
# 40352  gi|1572539552|emb|VDD88845.1| RuBisCO long cha...
# 40354  gi|1572539654|emb|VDD88919.1| RuBisCO long cha...
# 40359  gi|1572539352|emb|VDD88682.1| RuBisCO long cha...
# 40368  gi|1572539620|emb|VDD88893.1| RuBisCO long cha...
# 40371  gi|1572540049|emb|VDD89062.1| RuBisCO long cha...
# 40397  gi|500137273|ref|WP_011813278.1| ribulose-bisp...
# 40410  gi|1572540139|emb|VDD89124.1| RuBisCO long cha...
# 40412  gi|1572540117|emb|VDD89110.1| RuBisCO long cha...
# 40413  gi|1572539414|emb|VDD88743.1| RuBisCO long cha...
# 40418  gi|1572540207|emb|VDD89172.1| RuBisCO long cha...
# 40430  gi|1572539486|emb|VDD88788.1| RuBisCO long cha...
# 40454  gi|1572540251|emb|VDD89211.1| RuBisCO long cha...
# 40455  gi|1572540197|emb|VDD89167.1| RuBisCO long cha...
# 40456  gi|1572539444|emb|VDD88763.1| RuBisCO long cha...
# 40464  gi|563911827|ref|WP_023807801.1| ribulose-bisp...
# 40467  gi|1572539492|emb|VDD88791.1| RuBisCO long cha...
# 40476  gi|1572539460|emb|VDD88771.1| RuBisCO long cha...
# 40482  gi|1277787165|gb|PIU03070.1| ribulose-bisphosp...
# 40487  gi|499775450|ref|WP_011456184.1| ribulose-bisp...
# 40488  gi|1572539632|emb|VDD88902.1| RuBisCO long cha...
# 40494  TARA_039.SAMEA2620106.270.0.1-0.22_378_10 /ann...
#
#                                                       ID           Organism  \
# 6      gi|2978568|gb|AAC38280.1| ribulose-1,5-bisphos...          reference
# 41     gi|1572540067|emb|VDD89078.1| RuBisCO long cha...       Amesbacteria
# 42     gi|1572539574|emb|VDD88866.1| RuBisCO long cha...      Micrarchaeota
# 54     gi|494803605|ref|WP_007539013.1| type III ribu...          reference
# 56     gi|1572540253|emb|VDD89214.1| RuBisCO long cha...      Micrarchaeota
# 60     gi|504680960|ref|WP_014868062.1| type III ribu...          reference
# 62     gi|1572539949|emb|VDD88980.1| RuBisCO long cha...      Pacearchaeota
# 72     gi|1572540177|emb|VDD89155.1| RuBisCO long cha...    Aenigmarchaeota
# 86     gi|495596802|ref|WP_008321381.1| type III ribu...          reference
# 229    gi|1572540261|emb|VDD89218.1| RuBisCO long cha...      Pacearchaeota
# 272    gi|166078534|gb|ABY81245.1| ribulose-1,5-bisph...          reference
# 357    gi|738479616|ref|WP_036429835.1| form I ribulo...          reference
# 623    gi|30749269|pdb|1IWA|A Chain A, Rubisco From G...          reference
# 644    gi|497544748|ref|WP_009858946.1| form I ribulo...          reference
# 874    gi|37087672|sp|O58677.1|RBL_PYRHO RecName: Ful...          reference
# 1164   gi|1384872478|gb|AWF83650.1| ribulose-1,5-bisp...          reference
# 1314   gi|1572540025|emb|VDD89045.1| RuBisCO long cha...      Pacearchaeota
# 1646   gi|158512861|sp|A2SFV1.1|RBL1A_METPP RecName: ...          reference
# 1779   gi|1572541061|emb|VDS11157.1| RuBisCO long cha...      Pacearchaeota
# 1836   gi|1572540039|emb|VDD89054.1| RuBisCO long cha...      Pacearchaeota
# 2135   gi|1220464692|gb|ASO45429.1| ribulose-1,5-bisp...          reference
# 2345   gi|1572539973|emb|VDD89004.1| RuBisCO long cha...      Pacearchaeota
# 2560   gi|488805187|ref|WP_002717593.1| form I ribulo...          reference
# 3108   gi|502433156|ref|WP_012784207.1| form I ribulo...          reference
# 3310   gi|1572540293|emb|VDD89243.1| RuBisCO long cha...      Micrarchaeota
# 3490   gi|1572540055|emb|VDD89065.1| RuBisCO long cha...      Pacearchaeota
# 3655   gi|1572539518|emb|VDD88815.1| RuBisCO long cha...      Pacearchaeota
# 3755   gi|1572539975|emb|VDD89005.1| RuBisCO long cha...      Pacearchaeota
# 4024   gi|132051|sp|P00875.1|RBL_SPIOL RecName: Full=...          reference
# 4761   gi|3183144|sp|Q51856.1|RBL_HYDTE RecName: Full...          reference
# ...                                                  ...                ...
# 40265  gi|1278357258|gb|PIY97215.1| ribulose-bisphosp...      Parcubacteria
# 40266  gi|1572539540|emb|VDD88835.1| RuBisCO long cha...     Falkowbacteria
# 40267  gi|1572539494|emb|VDD88792.1| RuBisCO long cha...      Micrarchaeota
# 40270  gi|1572540083|emb|VDD89090.1| RuBisCO long cha...      Micrarchaeota
# 40272  gi|1572540003|emb|VDD89030.1| RuBisCO long cha...      Micrarchaeota
# 40275  gi|1572540249|emb|VDD89207.1| RuBisCO long cha...     Woesearchaeota
# 40305  gi|1572541021|emb|VDS11137.1| RuBisCO long cha...            unknown
# 40341  gi|1572540511|emb|VDD89260.1| RuBisCO long cha...            unknown
# 40345  gi|1572540513|emb|VDD89261.1| RuBisCO long cha...  Peregrinibacteria
# 40352  gi|1572539552|emb|VDD88845.1| RuBisCO long cha...      Micrarchaeota
# 40354  gi|1572539654|emb|VDD88919.1| RuBisCO long cha...      Pacearchaeota
# 40359  gi|1572539352|emb|VDD88682.1| RuBisCO long cha...      Pacearchaeota
# 40368  gi|1572539620|emb|VDD88893.1| RuBisCO long cha...      Pacearchaeota
# 40371  gi|1572540049|emb|VDD89062.1| RuBisCO long cha...      Pacearchaeota
# 40397  gi|500137273|ref|WP_011813278.1| ribulose-bisp...          reference
# 40410  gi|1572540139|emb|VDD89124.1| RuBisCO long cha...      Pacearchaeota
# 40412  gi|1572540117|emb|VDD89110.1| RuBisCO long cha...      Micrarchaeota
# 40413  gi|1572539414|emb|VDD88743.1| RuBisCO long cha...  Gottesmanbacteria
# 40418  gi|1572540207|emb|VDD89172.1| RuBisCO long cha...  Gottesmanbacteria
# 40430  gi|1572539486|emb|VDD88788.1| RuBisCO long cha...      Pacearchaeota
# 40454  gi|1572540251|emb|VDD89211.1| RuBisCO long cha...      Micrarchaeota
# 40455  gi|1572540197|emb|VDD89167.1| RuBisCO long cha...      Micrarchaeota
# 40456  gi|1572539444|emb|VDD88763.1| RuBisCO long cha...      Micrarchaeota
# 40464  gi|563911827|ref|WP_023807801.1| ribulose-bisp...          reference
# 40467  gi|1572539492|emb|VDD88791.1| RuBisCO long cha...      Pacearchaeota
# 40476  gi|1572539460|emb|VDD88771.1| RuBisCO long cha...      Pacearchaeota
# 40482  gi|1277787165|gb|PIU03070.1| ribulose-bisphosp...     Diapherotrites
# 40487  gi|499775450|ref|WP_011456184.1| ribulose-bisp...          reference
# 40488  gi|1572539632|emb|VDD88902.1| RuBisCO long cha...      Parcubacteria
# 40494  TARA_039.SAMEA2620106.270.0.1-0.22_378_10 /ann...      Nanoarchaeota
#
#           type
# 6           II
# 41        IIIb
# 42        IIIb
# 54        IIIb
# 56        IIIb
# 60        IIIb
# 62        IIIb
# 72        IIIb
# 86        IIIb
# 229       IIIb
# 272          I
# 357          I
# 623          I
# 644          I
# 874       IIIb
# 1164         I
# 1314      IIIb
# 1646         I
# 1779      IIIb
# 1836      IIIb
# 2135         I
# 2345   IIIlike
# 2560         I
# 3108         I
# 3310      IIIb
# 3490   IIIlike
# 3655      IIIb
# 3755   IIIlike
# 4024         I
# 4761         I
# ...        ...
# 40265     IIIc
# 40266     IIIc
# 40267     IIIb
# 40270     IIIb
# 40272     IIIb
# 40275     IIIb
# 40305     IIIb
# 40341     IIIb
# 40345  unknown
# 40352     IIIb
# 40354     IIIb
# 40359     IIIb
# 40368  IIIlike
# 40371     IIIb
# 40397       IV
# 40410     IIIb
# 40412     IIIb
# 40413     IIIc
# 40418     IIIc
# 40430     IIIb
# 40454  unknown
# 40455     IIIb
# 40456     IIIb
# 40464       IV
# 40467     IIIb
# 40476     IIIb
# 40482     IIIb
# 40487       IV
# 40488       IV
# 40494     IIIb
#
# [470 rows x 13 columns]
